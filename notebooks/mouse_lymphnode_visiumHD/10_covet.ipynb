# %%
import scenvi 
import scanpy as sc
import pandas as pd
import numpy as np

# %%
from tqdm import tqdm
for part in tqdm(['1a', '1b', '1c', '1d']):

    st_data = sc.read_h5ad(f'/ix/djishnu/shared/djishnu_kor11/training_data_2025/mouse_lymph{part}_visiumHD.h5ad')
    st_data.obsm['COVET'], st_data.obsm['COVET_SQRT'], st_data.uns['CovGenes'] = scenvi.compute_covet(st_data)

    np.save(
        f'/ix/djishnu/shared/djishnu_kor11/covet_outputs/mouse_lymphnode_visiumHD/mouse_lymph{part}_visiumHD_COVET.npy', 
        st_data.obsm['COVET']
    )

    np.save(
        f'/ix/djishnu/shared/djishnu_kor11/covet_outputs/mouse_lymphnode_visiumHD/mouse_lymph{part}_visiumHD_COVET_SQRT.npy', 
        st_data.obsm['COVET_SQRT']
    )
# Out:
# 100%|██████████| 4/4 [04:52<00:00, 73.25s/it]

# %%
import scanpy as sc 
import numpy as np 
import pandas as pd 

import sys
sys.path.append('../../src')

from spaceoracle.tools.network import RegulatoryFactory
from spaceoracle.gene_factory import GeneFactory
from spaceoracle.astronomer import Astronaut

# %%
part = '1a'
base_dir = '/ix/djishnu/shared/djishnu_kor11/'

co_grn = RegulatoryFactory(
    colinks_path=base_dir + f'training_data_2025/mouse_lymph1_visiumHD_colinks.pkl',
    annot='cell_type_int'
)

adata = sc.read_h5ad(f'/ix/djishnu/shared/djishnu_kor11/training_data_2025/mouse_lymph{part}_visiumHD.h5ad')

sp_maps = np.load(f'/ix/djishnu/shared/djishnu_kor11/covet_outputs/mouse_lymphnode_visiumHD/mouse_lymph{part}_visiumHD_COVET.npy')
feature_key = 'COVET'
adata.obsm['COVET'] = sp_maps

neil = Astronaut(
    adata=adata,
    annot='cell_type_int', 
    max_epochs=100, 
    learning_rate=5e-3, 
    spatial_dim=64,
    batch_size=512,
    grn=co_grn,
    radius=800,
    contact_distance=50,
    save_dir=base_dir + f'covet_runs/mouse_lymph{part}_visiumHD'
)

neil.run(sp_maps_key='COVET')
# Out:
# <style>
# .enlighten-fg-green {
#   color: #00cd00;
# }
# .enlighten-fg-red {
#   color: #cd0000;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>🕵️️  1 agents   0%|<span class="enlighten-fg-green">                                     </span>|    2/2116 [10:10&lt;7d 11h 05:21, 0.00 genes/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Rbfa 100%|<span class="enlighten-fg-red">██████████████████████████████████████████</span>| 2232400/2232400 [05:10&lt;00:00, 7206.52 cells/s]</pre>
#   </div>
# </div>
# warning: cell_thresholds not found in adata.uns
# Using COVET as spatial maps
# Fitting Itm2a with 302 modulators
# 	16 Transcription Factors
# 	251 Ligand-Receptor Pairs
# 	35 TranscriptionFactor-Ligand Pairs
# 0.4275
# warning: cell_thresholds not found in adata.uns
# Using COVET as spatial maps
# Fitting Rbfa with 338 modulators
# 	24 Transcription Factors
# 	251 Ligand-Receptor Pairs
# 	63 TranscriptionFactor-Ligand Pairs
# -0.8812
# warning: cell_thresholds not found in adata.uns
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 28
#      13 adata.obsm['COVET'] = sp_maps
#      15 neil = Astronaut(
#      16     adata=adata,
#      17     annot='cell_type_int',
#    (...)
#      25     save_dir=base_dir + f'covet_runs/mouse_lymph{part}_visiumHD'
#      26 )
# ---> 28 neil.run(sp_maps_key='COVET')
#
# File /ix/djishnu/alw399/SpaceOracle/notebooks/mouse_lymphnode_visiumHD/../../src/spaceoracle/astronomer.py:75, in Astronaut.run(self, sp_maps_key)
#      71     continue
#      73 self.queue.create_lock(gene)
# ---> 75 estimator.fit(
#      76     num_epochs=self.max_epochs,
#      77     learning_rate=self.learning_rate,
#      78     batch_size=self.batch_size,
#      79     pbar=train_bar
#      80 )
#      82 estimator.betadata.to_parquet(f'{self.save_dir}/{gene}_betadata.parquet')
#      84 self.trained_genes.append(gene)
#
# File /ix/djishnu/alw399/SpaceOracle/notebooks/mouse_lymphnode_visiumHD/../../src/spaceoracle/models/adapted_estimators.py:170, in PrefeaturizedCellularProgramsEstimator.fit(self, num_epochs, learning_rate, batch_size, pbar)
#     168 def fit(self, num_epochs=100, learning_rate=5e-3, batch_size=512, pbar=None):
# --> 170     sp_maps, X, y = self.init_data()
#     171     print(f'Using {self.sp_maps_key} as spatial maps')
#     173     self.models = {}
#
# File /ix/djishnu/alw399/SpaceOracle/notebooks/mouse_lymphnode_visiumHD/../../src/spaceoracle/models/adapted_estimators.py:102, in PrefeaturizedCellularProgramsEstimator.init_data(self)
#      96 counts_df, cell_thresholds = lr_info
#      98 if not all(
#      99     hasattr(self.adata.uns, attr)
#     100     for attr in ['received_ligands', 'received_ligands_tfl']
#     101 ):
# --> 102     self.adata = init_received_ligands(
#     103         self.adata,
#     104         radius=self.radius,
#     105         contact_distance=self.contact_distance,
#     106         cell_threshes=cell_thresholds
#     107     )
#     109 if len(self.lr['pairs']) > 0:
#     111     self.adata.uns['ligand_receptor'] = self.ligands_receptors_interactions(
#     112         self.adata.uns['received_ligands'][self.ligands],
#     113         get_filtered_df(counts_df, cell_thresholds, self.receptors)[self.receptors]
#     114     )
#
# File /ix/djishnu/alw399/SpaceOracle/notebooks/mouse_lymphnode_visiumHD/../../src/spaceoracle/models/parallel_estimators.py:137, in init_received_ligands(adata, radius, contact_distance, cell_threshes, layer)
#     129 ligands = np.unique(lr.ligand)
#     131 adata.uns['received_ligands'] = received_ligands(
#     132     xy=adata.obsm['spatial'],
#     133     ligands_df=get_filtered_df(counts_df, cell_thresholds=cell_threshes, genes=ligands),
#     134     lr_info=lr
#     135 )
# --> 137 adata.uns['received_ligands_tfl'] = received_ligands(
#     138     xy=adata.obsm['spatial'],
#     139     ligands_df=get_filtered_df(counts_df, None, genes=ligands), # Only Commot LRs should be filtered
#     140     lr_info=lr
#     141 )
#     143 return adata
#
# File /ix/djishnu/alw399/SpaceOracle/notebooks/mouse_lymphnode_visiumHD/../../src/spaceoracle/models/parallel_estimators.py:79, in received_ligands(xy, ligands_df, lr_info, scale_factor)
#      76 for radius in lr_info['radius'].unique():
#      77     radius_ligands = lr_info[lr_info['radius'] == radius]['ligand'].values
#      78     full_df.append(
# ---> 79         compute_radius_weights(
#      80             xy, ligands_df[radius_ligands], radius, scale_factor
#      81         )
#      82     )
#      84 full_df = pd.concat([df for df in full_df if not df.empty], axis=1)
#      85 full_df = full_df.reindex(ligands_df.index).reindex(ligands_df.columns, axis=1).fillna(0)
#
# File /ix/djishnu/alw399/SpaceOracle/notebooks/mouse_lymphnode_visiumHD/../../src/spaceoracle/models/parallel_estimators.py:56, in compute_radius_weights(xy, lig_df, radius, scale_factor)
#      54 u_ligands = list(np.unique(ligands))
#      55 lig_df_values = lig_df[u_ligands].values
# ---> 56 weighted_ligands = calculate_weighted_ligands(
#      57     gauss_weights, lig_df_values, u_ligands)
#      59 return pd.DataFrame(
#      60     weighted_ligands,
#      61     index=u_ligands,
#      62     columns=lig_df.index
#      63 ).T
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      26 # Keep unpickled object via `numba_unpickle` alive.
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#      44     key = (address, hashed)
#
# KeyboardInterrupt:
