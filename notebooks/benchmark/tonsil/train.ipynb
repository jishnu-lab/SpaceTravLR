# %%
import scanpy as sc 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

import sys
sys.path.append('../../../src')

from spaceoracle.tools.network import RegulatoryFactory
from spaceoracle.gene_factory import GeneFactory
from spaceoracle.astronomer import Astronaut

# %%
base_dir = '/ix/djishnu/shared/djishnu_kor11/'

co_grn = RegulatoryFactory(
    colinks_path=base_dir + 'training_data_2025/snrna_human_tonsil_colinks.pkl',
    annot='cell_type_int'
)

adata = sc.read_h5ad(base_dir + 'training_data_2025/snrna_human_tonsil.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 5778 × 3333
#     obs: 'cell_type', 'author_cell_type', 'cell_type_int', 'banksy_celltypes'
#     uns: 'cell_thresholds', 'cell_type_int_colors', 'received_ligands', 'received_ligands_tfl'
#     obsm: 'spatial', 'spatial_unscaled'
#     layers: 'imputed_count', 'normalized_count'

# %%
del adata.uns['received_ligands']
del adata.uns['received_ligands_tfl']

# %%
# Remove pre-processing from COMMOT
adata.uns['cell_thresholds'] = pd.DataFrame(
    index=adata.obs.index, 
    columns=adata.var_names).fillna(1)

# %%
sp_maps = pd.read_parquet('/ix/djishnu/shared/djishnu_kor11/scGPT_outputs/tonsil_embeddings.parquet')
sp_maps = sp_maps.reindex(adata.obs.index, axis=0).values
sp_maps.shape
# Out:
# (5778, 512)

# %%
feature_key = 'scGPT'
adata.obsm['scGPT'] = sp_maps

# %%
neil = Astronaut(
    adata=adata,
    annot='cell_type_int', 
    max_epochs=100, 
    learning_rate=5e-3, 
    # spatial_dim=64, # used to create the spatial maps
    batch_size=512,
    grn=co_grn,
    radius=400,
    contact_distance=50,
    save_dir=base_dir + 'scGPT_runs/tonsil'
)

# %%
# We shouldn't use the anchors here, because those are part of our CNN model

neil.run(sp_maps_key='scGPT', use_anchors=False)
# Out:
# <style>
# .enlighten-fg-green {
#   color: #00cd00;
# }
# .enlighten-fg-red {
#   color: #cd0000;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>🕵️️  1 agents   0%|<span class="enlighten-fg-green">▏                                     </span>|   10/3333 [13:30&lt;3d 2h 48:42, 0.01 genes/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>SCX | 3/13  59%|<span class="enlighten-fg-red">██████████████████████▌               </span>| 342545/577800 [00:53&lt;00:36, 6470.53 cells/s]</pre>
#   </div>
# </div>
# Using scGPT as spatial maps
# Fitting TOP2A with 1038 modulators
# 	21 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	59 TranscriptionFactor-Ligand Pairs
# 0: 0.8952 | 0.8028
# 1: 0.9112 | 0.9129
# 2: 0.7566 | 0.7487
# 3: 0.9838 | 0.9780
# 4: 0.8242 | 0.8106
# 5: 0.6670 | 0.6541
# 6: 0.4955 | 0.4435
# 7: 0.9511 | 0.9481
# 8: 0.7477 | 0.7423
# 9: 0.9168 | 0.9168
# 10: 0.9977 | 0.9978
# 11: 0.9424 | 0.9620
# 12: 0.9905 | 0.9902
# Using scGPT as spatial maps
# Fitting CD6 with 1036 modulators
# 	22 Transcription Factors
# 	956 Ligand-Receptor Pairs
# 	58 TranscriptionFactor-Ligand Pairs
# 0: 0.9887 | 0.9876
# 1: 0.9252 | 0.9333
# 2: 0.7353 | 0.7216
# 3: 0.9882 | 0.9888
# 4: 0.7254 | 0.7351
# 5: 0.7390 | 0.7204
# 6: 0.4979 | 0.4717
# 7: 0.9389 | 0.9394
# 8: 0.6999 | 0.6818
# 9: 0.9880 | 0.9884
# 10: 0.9279 | 0.9453
# 11: 0.9992 | 0.9992
# 12: 0.8946 | 0.8932
# Using scGPT as spatial maps
# Fitting GALM with 1014 modulators
# 	14 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	42 TranscriptionFactor-Ligand Pairs
# 0: 0.8963 | 0.8472
# 1: 0.7966 | 0.7913
# 2: 0.4580 | 0.4374
# 3: 0.8792 | 0.8792
# 4: 0.6287 | 0.6184
# 5: 0.7489 | 0.7208
# 6: 0.3958 | 0.3778
# 7: 0.6378 | 0.6257
# 8: 0.4334 | 0.4065
# 9: 0.9218 | 0.9176
# 10: 0.9148 | 0.9176
# 11: 0.9997 | 0.9997
# 12: 0.7922 | 0.7849
# Using scGPT as spatial maps
# Fitting MARVELD3 with 1063 modulators
# 	28 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	77 TranscriptionFactor-Ligand Pairs
# 0: 0.7361 | 0.7138
# 1: 1.0000 | 1.0000
# 2: x.xxxx | 0.1933
# 3: 0.9894 | 0.9887
# 4: 0.7417 | 0.7548
# 5: 0.5225 | 0.5549
# 6: 1.0000 | 1.0000
# 7: 1.0000 | 1.0000
# 8: 1.0000 | 1.0000
# 9: 1.0000 | 1.0000
# 10: 1.0000 | 1.0000
# 11: 1.0000 | 1.0000
# 12: 0.7182 | 0.7538
# Using scGPT as spatial maps
# Fitting NPY1R with 1047 modulators
# 	20 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	69 TranscriptionFactor-Ligand Pairs
# 0: 0.3860 | 0.4931
# 1: 1.0000 | 1.0000
# 2: 1.0000 | 1.0000
# 3: 0.9875 | 0.9877
# 4: 1.0000 | 1.0000
# 5: 1.0000 | 1.0000
# 6: 1.0000 | 1.0000
# 7: 1.0000 | 1.0000
# 8: 1.0000 | 1.0000
# 9: 1.0000 | 1.0000
# 10: 0.8483 | 0.8645
# 11: 1.0000 | 1.0000
# 12: 1.0000 | 1.0000
# Using scGPT as spatial maps
# Fitting PDK1 with 1057 modulators
# 	27 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	72 TranscriptionFactor-Ligand Pairs
# 0: 0.5798 | 0.5663
# 1: 0.6643 | 0.6783
# 2: 0.8641 | 0.8640
# 3: 0.9896 | 0.9908
# 4: 0.4659 | 0.4730
# 5: 0.9076 | 0.9013
# 6: 0.7301 | 0.7312
# 7: 0.9685 | 0.9764
# 8: 0.5179 | 0.5226
# 9: 0.8998 | 0.8877
# 10: 0.9724 | 0.9768
# 11: 0.9978 | 0.9981
# 12: 0.9765 | 0.9729
# Using scGPT as spatial maps
# Fitting MYO1D with 1057 modulators
# 	28 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	71 TranscriptionFactor-Ligand Pairs
# 0: 0.9069 | 0.9007
# 1: 0.4629 | 0.4593
# 2: 0.8038 | 0.7963
# 3: 0.9865 | 0.9859
# 4: 0.7097 | 0.7002
# 5: 0.7424 | 0.7364
# 6: 0.6380 | 0.6286
# 7: 0.9572 | 0.9704
# 8: 0.5029 | 0.5080
# 9: 0.9918 | 0.9925
# 10: 0.9974 | 0.9977
# 11: 0.9932 | 0.9923
# 12: 0.9522 | 0.9531
# Using scGPT as spatial maps
# Fitting LMO2 with 1104 modulators
# 	42 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	104 TranscriptionFactor-Ligand Pairs
# 0: 0.9620 | 0.9551
# 1: 0.9295 | 0.9301
# 2: 0.7031 | 0.6933
# 3: 0.9980 | 0.9984
# 4: 0.4885 | 0.4932
# 5: 1.0000 | 1.0000
# 6: 1.0000 | 1.0000
# 7: 1.0000 | 1.0000
# 8: 0.8194 | 0.8257
# 9: 0.9963 | 0.9966
# 10: 0.9987 | 0.9991
# 11: 1.0000 | 1.0000
# 12: 0.9881 | 0.9879
# Using scGPT as spatial maps
# Fitting SMPD3 with 1021 modulators
# 	20 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	43 TranscriptionFactor-Ligand Pairs
# 0: 0.7659 | 0.6285
# 1: 0.8166 | 0.8215
# 2: 0.3045 | 0.3024
# 3: 0.9860 | 0.9888
# 4: 0.5206 | 0.5350
# 5: 0.3794 | 0.3404
# 6: 0.5784 | 0.5451
# 7: 0.8498 | 0.9483
# 8: 0.4901 | 0.4817
# 9: 0.9521 | 0.9512
# 10: 0.9809 | 0.9810
# 11: 0.9467 | 0.9552
# 12: 0.7435 | 0.7236
# Using scGPT as spatial maps
# Fitting DEPTOR with 1014 modulators
# 	15 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	41 TranscriptionFactor-Ligand Pairs
# 0: 0.3418 | 0.2753
# 1: 0.6053 | 0.6101
# 2: 0.2538 | 0.2373
# 3: 0.9844 | 0.9840
# 4: 0.6166 | 0.6204
# 5: 0.4123 | 0.3743
# 6: 0.7977 | 0.7741
# 7: 1.0000 | 1.0000
# 8: 1.0000 | 1.0000
# 9: 0.9603 | 0.9585
# 10: 0.9695 | 0.9681
# 11: 1.0000 | 1.0000
# 12: 0.6999 | 0.6948
# Using scGPT as spatial maps
# Fitting SCX with 1068 modulators
# 	32 Transcription Factors
# 	958 Ligand-Receptor Pairs
# 	78 TranscriptionFactor-Ligand Pairs
# 0: 0.6293 | 0.6085
# 1: 0.8353 | 0.8845
# 2: 0.7311 | 0.7277
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 neil.run(sp_maps_key='scGPT')
#
# File /ix3/djishnu/alw399/SpaceOracle/notebooks/benchmark/tonsil/../../../src/spaceoracle/astronomer.py:68, in Astronaut.run(self, sp_maps_key)
#      64     continue
#      66 self.queue.create_lock(gene)
# ---> 68 estimator.fit(
#      69     num_epochs=self.max_epochs,
#      70     threshold_lambda=self.threshold_lambda,
#      71     learning_rate=self.learning_rate,
#      72     batch_size=self.batch_size,
#      73     pbar=train_bar
#      74 )
#      76 estimator.betadata.to_parquet(f'{self.save_dir}/{gene}_betadata.parquet')
#      78 self.trained_genes.append(gene)
#
# File /ix3/djishnu/alw399/SpaceOracle/notebooks/benchmark/tonsil/../../../src/spaceoracle/models/adapted_estimators.py:237, in PrefeaturizedCellularProgramsEstimator.fit(self, num_epochs, threshold_lambda, learning_rate, batch_size, pbar, estimator, score_threshold, use_anchors)
#     225 groups = np.array(groups)
#     226 gl = GroupLasso(
#     227     groups=groups,
#     228     group_reg=threshold_lambda,
#    (...)
#     235     tol=1e-5,
#     236 )
# --> 237 gl.fit(X_cell, y_cell)
#     238 y_pred = gl.predict(X_cell)
#     239 coefs = gl.coef_.flatten()
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_group_lasso.py:681, in GroupLasso.fit(self, X, y, lipschitz)
#     668 def fit(self, X, y, lipschitz=None):
#     669     """Fit a group lasso regularised linear regression model.
#     670
#     671     Parameters
#    (...)
#     679         data and target matrices. If None, this is estimated.
#     680     """
# --> 681     return super().fit(X, y, lipschitz=lipschitz)
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_group_lasso.py:463, in BaseGroupLasso.fit(self, X, y, lipschitz)
#     460 """Fit a group-lasso regularised linear model.
#     461 """
#     462 self._init_fit(X, y, lipschitz=lipschitz)
# --> 463 self._minimise_loss()
#     464 self.intercept_ -= (self._X_means_ @ self.coef_).reshape(
#     465     self.intercept_.shape
#     466 )
#     467 return self
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_group_lasso.py:376, in BaseGroupLasso._minimise_loss(self)
#     364 weights = _join_intercept(self.intercept_, self.coef_)
#     365 optimiser = FISTAProblem(
#     366     self.subsampler_.subsample_apply(
#     367         self._unregularised_loss, self.X_aug_, self.y_
#    (...)
#     374     self.lipschitz_,
#     375 )
# --> 376 weights = optimiser.minimise(
#     377     weights, n_iter=self.n_iter, tol=self.tol, callback=callback
#     378 )
#     379 self.lipschitz_ = optimiser.lipschitz
#     380 self.intercept_, self.coef_ = _split_intercept(weights)
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_fista.py:70, in FISTAProblem.minimise(self, x0, n_iter, tol, callback)
#      67 previous_x = optimal_x
#      69 # Simple FISTA update step
# ---> 70 new_optimal_x, new_momentum_x, new_momentum = self._update_step(
#      71     previous_x, momentum_x, momentum, self.lipschitz
#      72 )
#      74 # Adaptive restart criterion from Equation 12 in O’Donoghue & Candès (2012)
#      75 generalised_gradient = momentum_x.ravel() - new_optimal_x.ravel()
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_fista.py:46, in FISTAProblem._update_step(self, x, momentum_x, momentum, lipschitz)
#      45 def _update_step(self, x, momentum_x, momentum, lipschitz):
# ---> 46     intermediate_step = 0.5 * self.smooth_grad(momentum_x) / lipschitz
#      47     new_x = self.prox(momentum_x - intermediate_step, lipschitz)
#      48     new_momentum = self.compute_next_momentum(momentum)
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_subsampling.py:115, in Subsampler.subsample_apply.<locals>.new_f(*args, **kwargs)
#     112 @wraps(f)
#     113 def new_f(*args, **kwargs):
#     114     subsampled_inputs = self.subsample(*full_inputs)
# --> 115     return f(*subsampled_inputs, *args, **kwargs)
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_group_lasso.py:300, in BaseGroupLasso._unregularised_gradient(self, X_aug, y, w)
#     299 def _unregularised_gradient(self, X_aug, y, w):
# --> 300     g = self._grad(X_aug, y, w)
#     301     if not self.fit_intercept:
#     302         g[0] = 0
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_group_lasso.py:699, in GroupLasso._grad(self, X_aug, y, w)
#     698 def _grad(self, X_aug, y, w):
# --> 699     SSE_grad = _l2_grad(X_aug, y, w)
#     700     return SSE_grad / X_aug.shape[0]
#
# File /ix3/djishnu/alw399/envs/sheep/lib/python3.9/site-packages/group_lasso/_group_lasso.py:545, in _l2_grad(A, b, x)
#     542 def _l2_grad(A, b, x):
#     543     """The gradient of the problem ||Ax - b||^2 wrt x.
#     544     """
# --> 545     return A.T @ (A @ x - b)
#
# KeyboardInterrupt:
