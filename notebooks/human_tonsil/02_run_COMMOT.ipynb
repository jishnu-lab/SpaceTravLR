# %%
import commot as ct
import scanpy as sc
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ### Run Commot

# %%
adata = sc.read_h5ad('/ix/djishnu/shared/djishnu_kor11/training_data_2025/snrna_human_tonsil.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 5778 × 3549
#     obs: 'cell_type', 'author_cell_type', 'cell_type_int', 'leiden', 'leiden_R', 'cell_type_2'
#     uns: 'author_cell_type_colors', 'cell_thresholds', 'cell_type_2_colors', 'cell_type_colors', 'dendrogram_leiden', 'leiden', 'leiden_R', 'leiden_colors', 'ligand_receivers', 'neighbors', 'pca', 'received_ligands', 'received_ligands_tfl', 'umap'
#     obsm: 'X_pca', 'X_umap', 'ora_estimate', 'ora_pvals', 'spatial', 'spatial_unscaled'
#     varm: 'PCs'
#     layers: 'imputed_count', 'normalized_count'
#     obsp: 'connectivities', 'distances'

# %%
# adata.X = adata.layers['imputed_count']
adata.X = adata.layers['normalized_count']

# %%
df_ligrec = ct.pp.ligand_receptor_database(
    database='CellChat', 
    species='human', 
    signaling_type=None
)
    
df_ligrec.columns = ['ligand', 'receptor', 'pathway', 'signaling']  

df_ligrec['name'] = df_ligrec['ligand'] + '-' + df_ligrec['receptor']
len(df_ligrec['name'].unique())
# Out:
# 1938

# %%
import sys
sys.path.append('../../src')
from spaceoracle.tools.network import expand_paired_interactions

expanded = expand_paired_interactions(df_ligrec)
genes = set(expanded.ligand) | set(expanded.receptor)
genes = list(genes)

expanded
# Out:
#      ligand receptor pathway           signaling                 name
# 0     TGFB1   TGFBR1    TGFb  Secreted Signaling  TGFB1-TGFBR1_TGFBR2
# 0     TGFB1   TGFBR2    TGFb  Secreted Signaling  TGFB1-TGFBR1_TGFBR2
# 1     TGFB2   TGFBR1    TGFb  Secreted Signaling  TGFB2-TGFBR1_TGFBR2
# 1     TGFB2   TGFBR2    TGFb  Secreted Signaling  TGFB2-TGFBR1_TGFBR2
# 2     TGFB3   TGFBR1    TGFb  Secreted Signaling  TGFB3-TGFBR1_TGFBR2
# ...     ...      ...     ...                 ...                  ...
# 1936  ITGA9    VCAM1    VCAM   Cell-Cell Contact    ITGA9_ITGB1-VCAM1
# 1936  ITGB1    VCAM1    VCAM   Cell-Cell Contact    ITGA9_ITGB1-VCAM1
# 1937  ITGA4    VCAM1    VCAM   Cell-Cell Contact    ITGA4_ITGB7-VCAM1
# 1937  ITGB7    VCAM1    VCAM   Cell-Cell Contact    ITGA4_ITGB7-VCAM1
# 1938   VSIR   IGSF11   VISTA   Cell-Cell Contact          VSIR-IGSF11
#
# [2914 rows x 5 columns]

# %%
expanded = expanded[expanded.ligand.isin(adata.var_names) & expanded.receptor.isin(adata.var_names)]
expanded[expanded.ligand == 'IL7']
# Out:
#     ligand receptor pathway           signaling            name
# 726    IL7     IL7R     IL2  Secreted Signaling  IL7-IL7R_IL2RG

# %%
ct.tl.spatial_communication(adata,
    database_name='user_database', 
    # df_ligrec=df_ligrec, 
    df_ligrec=expanded, 
    dis_thr=200, 
    # heteromeric=True
    heteromeric=False
)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5778 × 3549
#     obs: 'cell_type', 'author_cell_type', 'cell_type_int', 'leiden', 'leiden_R', 'cell_type_2'
#     uns: 'author_cell_type_colors', 'cell_type_2_colors', 'cell_type_colors', 'dendrogram_leiden', 'leiden', 'leiden_R', 'leiden_colors', 'neighbors', 'pca', 'umap', 'commot-user_database-info'
#     obsm: 'X_pca', 'X_umap', 'ora_estimate', 'ora_pvals', 'spatial', 'spatial_unscaled', 'commot-user_database-sum-sender', 'commot-user_database-sum-receiver'
#     varm: 'PCs'
#     layers: 'imputed_count', 'normalized_count'
#     obsp: 'connectivities', 'distances', 'commot-user_database-COL4A4-SDC4', 'commot-user_database-COL4A4-ITGA9', 'commot-user_database-COL4A4-ITGB1', 'commot-user_database-COL4A4-ITGA1', 'commot-user_database-COL4A4-GP6', 'commot-user_database-COL4A4-ITGB8', 'commot-user_database-COL4A4-CD44', 'commot-user_database-COL4A4-ITGA10', 'commot-user_database-NRXN3-NLGN1', 'commot-user_database-NRXN3-NLGN3', 'commot-user_database-CCL2-CCR2', 'commot-user_database-NFASC-CNTN1', 'commot-user_database-NFASC-CNTNAP1', 'commot-user_database-COL9A2-SDC4', 'commot-user_database-COL9A2-ITGA9', 'commot-user_database-COL9A2-ITGB1', 'commot-user_database-COL9A2-ITGA1', 'commot-user_database-COL9A2-GP6', 'commot-user_database-COL9A2-ITGB8', 'commot-user_database-COL9A2-CD44', 'commot-user_database-COL9A2-ITGA10', 'commot-user_database-ICAM1-ITGB2', 'commot-user_database-ICAM1-ITGAX', 'commot-user_database-ICAM1-ITGAM', 'commot-user_database-ICAM1-SPN', 'commot-user_database-IL4-IL13RA1', 'commot-user_database-IL4-IL4R', 'commot-user_database-BMP6-BMPR2', 'commot-user_database-ICAM2-ITGB2', 'commot-user_database-ICAM2-ITGAM', 'commot-user_database-PECAM1-PECAM1', 'commot-user_database-ITGB2-ICAM1', 'commot-user_database-ITGB2-ICAM2', 'commot-user_database-ITGB2-CD226', 'commot-user_database-JAM3-ITGB2', 'commot-user_database-JAM3-JAM3', 'commot-user_database-JAM3-ITGAM', 'commot-user_database-TNR-SDC4', 'commot-user_database-TNR-ITGA9', 'commot-user_database-TNR-ITGB1', 'commot-user_database-TNR-ITGA8', 'commot-user_database-TNR-ITGA2B', 'commot-user_database-TIGIT-PVR', 'commot-user_database-TIGIT-NECTIN2', 'commot-user_database-CD226-PVR', 'commot-user_database-CD226-NECTIN2', 'commot-user_database-ITGA9-VCAM1', 'commot-user_database-COL6A3-SDC4', 'commot-user_database-COL6A3-ITGA9', 'commot-user_database-COL6A3-ITGB1', 'commot-user_database-COL6A3-ITGA1', 'commot-user_database-COL6A3-GP6', 'commot-user_database-COL6A3-ITGB8', 'commot-user_database-COL6A3-CD44', 'commot-user_database-COL6A3-ITGA10', 'commot-user_database-SEMA3A-PLXNA4', 'commot-user_database-SEMA3A-NRP1', 'commot-user_database-CNTN1-NRCAM', 'commot-user_database-C3-ITGB2', 'commot-user_database-C3-ITGAX', 'commot-user_database-C3-CR2', 'commot-user_database-C3-ITGAM', 'commot-user_database-IGF1-ITGA6', 'commot-user_database-IGF1-IGF1R', 'commot-user_database-NRG3-ERBB4', 'commot-user_database-CCL4-CCR5', 'commot-user_database-COL6A6-SDC4', 'commot-user_database-COL6A6-ITGA9', 'commot-user_database-COL6A6-ITGB1', 'commot-user_database-COL6A6-ITGA1', 'commot-user_database-COL6A6-GP6', 'commot-user_database-COL6A6-ITGB8', 'commot-user_database-COL6A6-CD44', 'commot-user_database-COL6A6-ITGA10', 'commot-user_database-CCL20-CCR6', 'commot-user_database-FREM1-ITGB1', 'commot-user_database-FREM1-ITGA8', 'commot-user_database-TNFSF9-TNFRSF9', 'commot-user_database-COL4A3-SDC4', 'commot-user_database-COL4A3-ITGA9', 'commot-user_database-COL4A3-ITGB1', 'commot-user_database-COL4A3-ITGA1', 'commot-user_database-COL4A3-GP6', 'commot-user_database-COL4A3-ITGB8', 'commot-user_database-COL4A3-CD44', 'commot-user_database-COL4A3-ITGA10', 'commot-user_database-CCL19-CCR7', 'commot-user_database-PDCD1LG2-PDCD1', 'commot-user_database-TNFSF13B-TNFRSF13B', 'commot-user_database-CXCL13-CXCR5', 'commot-user_database-CXCL13-CXCR3', 'commot-user_database-PTPRM-PTPRM', 'commot-user_database-GZMA-F2R', 'commot-user_database-GZMA-PARD3', 'commot-user_database-NPPC-NPR2', 'commot-user_database-DLL4-NOTCH1', 'commot-user_database-CDH4-CDH4', 'commot-user_database-SEMA6D-TYROBP', 'commot-user_database-SEMA6D-KDR', 'commot-user_database-EBI3-IL27RA', 'commot-user_database-EBI3-IL6ST', 'commot-user_database-PDGFD-PDGFRB', 'commot-user_database-FGF7-FGFR2', 'commot-user_database-FLT3LG-FLT3', 'commot-user_database-CD96-PVR', 'commot-user_database-CD96-NECTIN1', 'commot-user_database-COL4A1-SDC4', 'commot-user_database-COL4A1-ITGA9', 'commot-user_database-COL4A1-ITGB1', 'commot-user_database-COL4A1-ITGA1', 'co ...

# %%
adata.write_h5ad('commot.h5ad')
adata = sc.read_h5ad('commot.h5ad')

# %%
[x for x in adata.obsp.keys() if 'IL7' in x]
# Out:
# ['commot-user_database-IL7-IL7R']

# %%
# lr_info = {k.replace('commot-user_database-', ''): v for k, v in adata.obsp.items() if 'commot-user_database-' in k}
# len(lr_info)
# Out:
# 311

# %%
# df_ligrec = df_ligrec[df_ligrec['name'].isin(lr_info.keys())]
# df_ligrec['signaling'].value_counts()
# Out:
# signaling
# Cell-Cell Contact     69
# Secreted Signaling    46
# ECM-Receptor          42
# Name: count, dtype: int64

# %% [markdown]
# ### Get cluster communication scores

# %%
expanded['rename'] = expanded['ligand'] + '-' + expanded['receptor']

# %%
from tqdm import tqdm
import commot as ct

for name in tqdm(expanded['rename'].unique()):

    ct.tl.cluster_communication(adata, database_name='user_database', pathway_name=name, clustering='cell_type',
        random_seed=12, n_permutations=100)
# Out:
# 100%|██████████| 310/310 [24:22<00:00,  4.72s/it]

# %%
# adata.write_h5ad('commot_cluster.h5ad')
# adata = sc.read_h5ad('commot_cluster.h5ad')

# %%
[x for x in adata.uns.keys() if 'IL7' in x]
# Out:
# ['commot_cluster-cell_type-user_database-IL7-IL7R']

# %%
from collections import defaultdict
data_dict = defaultdict(dict)

for name in expanded['rename']:
    data_dict[name]['communication_matrix'] = adata.uns[f'commot_cluster-cell_type-user_database-{name}']['communication_matrix']
    data_dict[name]['communication_pvalue'] = adata.uns[f'commot_cluster-cell_type-user_database-{name}']['communication_pvalue']

import pickle
with open('/ix/djishnu/shared/djishnu_kor11/commot_outputs/tonsil_communication.pkl', 'wb') as f:
    pickle.dump(data_dict, f)

# %%
# check outputs

import pickle
with open('/ix/djishnu/shared/djishnu_kor11/commot_outputs/tonsil_communication.pkl', 'rb') as f:
    info = pickle.load(f)

len(info.keys())
# Out:
# 310

# %%
[x for x in info.keys() if 'IL7' in x]
# Out:
# ['IL7-IL7R']

# %%
def get_sig_interactions(value_matrix, p_matrix, pval=0.3):
    p_matrix = np.where(p_matrix < pval, 1, 0)
    return value_matrix * p_matrix

interactions = {}
for lig, rec in tqdm(zip(expanded['ligand'], expanded['receptor'])):
    name = lig + '-' + rec

    if name in info.keys():

        value_matrix = info[name]['communication_matrix']
        p_matrix = info[name]['communication_pvalue']

        sig_matrix = get_sig_interactions(value_matrix, p_matrix)
        
        if sig_matrix.sum().sum() > 0:
            interactions[name] = sig_matrix
    
len(interactions)
# Out:
# 473it [00:00, 643.95it/s]
# 310

# %% [markdown]
# ### Get expanded LR masks

# %%
interactions.keys()
# Out:
# dict_keys(['GDF7-BMPR2', 'BMP6-BMPR2', 'BMP7-BMPR2', 'BMP8A-BMPR2', 'WNT10A-LRP5', 'WNT10A-FZD7', 'WNT10A-FZD8', 'WNT10B-LRP5', 'WNT10B-FZD7', 'WNT10B-FZD8', 'WNT3-LRP5', 'WNT3-FZD7', 'WNT3-FZD8', 'WNT4-LRP5', 'WNT4-FZD7', 'WNT4-FZD8', 'WNT5B-FZD7', 'WNT5B-FZD8', 'NRG1-ERBB4', 'NRG2-ERBB4', 'NRG3-ERBB4', 'FGF7-FGFR2', 'PDGFD-PDGFRB', 'VEGFC-FLT4', 'VEGFC-KDR', 'IGF1-IGF1R', 'IGF1-ITGA6', 'CCL2-CCR2', 'CCL4-CCR5', 'CCL5-CCR5', 'CCL3-CCR5', 'CCL20-CCR6', 'CCL19-CCR7', 'CCL21-CCR7', 'CXCL9-CXCR3', 'CXCL10-CXCR3', 'CXCL13-CXCR3', 'CXCL12-CXCR4', 'CXCL13-CXCR5', 'CXCL16-CXCR6', 'IL4-IL4R', 'IL7-IL7R', 'IL15-IL2RB', 'IL4-IL13RA1', 'IL6-IL6R', 'IL6-IL6ST', 'EBI3-IL27RA', 'EBI3-IL6ST', 'IL18-IL18R1', 'IL18-IL18RAP', 'IL33-IL1RAP', 'IL34-CSF1R', 'CSF1-CSF1R', 'TNF-TNFRSF1A', 'TNF-TNFRSF1B', 'EDA-EDAR', 'TNFSF11-TNFRSF11A', 'TNFSF8-TNFRSF8', 'TNFSF9-TNFRSF9', 'TNFSF13B-TNFRSF13B', 'CD40LG-ITGA2B', 'CD40LG-ITGA5', 'CD40LG-ITGB1', 'CD40LG-ITGAM', 'CD40LG-ITGB2', 'ANGPTL1-ITGA1', 'ANGPTL1-ITGB1', 'C3-CR2', 'C3-ITGAM', 'C3-ITGB2', 'C3-ITGAX', 'TAC4-TACR1', 'GZMA-F2R', 'GZMA-PARD3', 'NPPC-NPR2', 'KITLG-KIT', 'FLT3LG-FLT3', 'SEMA3A-NRP1', 'SEMA3A-PLXNA4', 'SEMA3C-NRP1', 'SEMA3C-PLXNA4', 'SEMA3D-NRP1', 'SEMA3D-PLXNA4', 'SEMA3C-NRP2', 'SEMA3D-NRP2', 'SEMA3C-PLXND1', 'ANXA1-FPR1', 'GAS6-AXL', 'GAS6-MERTK', 'RARRES2-GPR1', 'RARRES2-CMKLR1', 'COL1A1-ITGA1', 'COL1A1-ITGB1', 'COL1A2-ITGA1', 'COL1A2-ITGB1', 'COL4A1-ITGA1', 'COL4A1-ITGB1', 'COL4A3-ITGA1', 'COL4A3-ITGB1', 'COL4A4-ITGA1', 'COL4A4-ITGB1', 'COL6A1-ITGA1', 'COL6A1-ITGB1', 'COL6A2-ITGA1', 'COL6A2-ITGB1', 'COL6A3-ITGA1', 'COL6A3-ITGB1', 'COL6A6-ITGA1', 'COL6A6-ITGB1', 'COL9A2-ITGA1', 'COL9A2-ITGB1', 'FN1-ITGB1', 'FN1-ITGA4', 'FN1-ITGA5', 'FN1-ITGA8', 'LAMA3-ITGA1', 'LAMA3-ITGB1', 'LAMA4-ITGA1', 'LAMA4-ITGB1', 'LAMC1-ITGA1', 'LAMC1-ITGB1', 'CHAD-ITGB1', 'RELN-ITGB1', 'THBS2-ITGB1', 'LAMA3-ITGA6', 'LAMA4-ITGA6', 'LAMC1-ITGA6', 'TNC-ITGA8', 'TNC-ITGB1', 'TNR-ITGA8', 'TNR-ITGB1', 'FRAS1-ITGA8', 'FRAS1-ITGB1', 'FREM1-ITGA8', 'FREM1-ITGB1', 'TNC-ITGA9', 'TNR-ITGA9', 'COL1A1-ITGA9', 'COL1A2-ITGA9', 'COL4A1-ITGA9', 'COL4A3-ITGA9', 'COL4A4-ITGA9', 'COL6A1-ITGA9', 'COL6A2-ITGA9', 'COL6A3-ITGA9', 'COL6A6-ITGA9', 'COL9A2-ITGA9', 'LAMA3-ITGA9', 'LAMA4-ITGA9', 'LAMC1-ITGA9', 'COL1A1-ITGA10', 'COL1A2-ITGA10', 'COL4A1-ITGA10', 'COL4A3-ITGA10', 'COL4A4-ITGA10', 'COL6A1-ITGA10', 'COL6A2-ITGA10', 'COL6A3-ITGA10', 'COL6A6-ITGA10', 'COL9A2-ITGA10', 'FN1-ITGB7', 'FN1-ITGA2B', 'TNC-ITGA2B', 'TNR-ITGA2B', 'FN1-ITGB8', 'LAMA3-ITGB8', 'LAMA4-ITGB8', 'LAMC1-ITGB8', 'COL1A1-ITGB8', 'COL1A2-ITGB8', 'COL4A1-ITGB8', 'COL4A3-ITGB8', 'COL4A4-ITGB8', 'COL6A1-ITGB8', 'COL6A2-ITGB8', 'COL6A3-ITGB8', 'COL6A6-ITGB8', 'COL9A2-ITGB8', 'FN1-CD44', 'COL1A1-CD44', 'COL1A2-CD44', 'COL4A1-CD44', 'COL4A3-CD44', 'COL4A4-CD44', 'COL6A1-CD44', 'COL6A2-CD44', 'COL6A3-CD44', 'COL6A6-CD44', 'COL9A2-CD44', 'LAMA3-CD44', 'LAMA4-CD44', 'LAMC1-CD44', 'COL1A1-SDC4', 'COL1A2-SDC4', 'COL4A1-SDC4', 'COL4A3-SDC4', 'COL4A4-SDC4', 'COL6A1-SDC4', 'COL6A2-SDC4', 'COL6A3-SDC4', 'COL6A6-SDC4', 'COL9A2-SDC4', 'FN1-SDC4', 'TNC-SDC4', 'TNR-SDC4', 'THBS2-SDC4', 'LAMA3-SV2A', 'LAMA4-SV2A', 'LAMC1-SV2A', 'THBS2-CD36', 'COL1A1-GP6', 'COL1A2-GP6', 'COL4A1-GP6', 'COL4A3-GP6', 'COL4A4-GP6', 'COL6A1-GP6', 'COL6A2-GP6', 'COL6A3-GP6', 'COL6A6-GP6', 'COL9A2-GP6', 'ADGRE5-CD55', 'ALCAM-CD6', 'ANXA1-FPR3', 'CADM1-CADM1', 'CD226-NECTIN2', 'CD226-PVR', 'FCER2-ITGAM', 'FCER2-ITGB2', 'FCER2-ITGAX', 'FCER2-CR2', 'ENTPD1-TMIGD3', 'CD40LG-CD40', 'CD6-ALCAM', 'CD80-CD274', 'CD80-CD28', 'CD80-CTLA4', 'CD86-CD28', 'CD86-CTLA4', 'CD96-NECTIN1', 'CD96-PVR', 'CDH4-CDH4', 'CDH2-CDH2', 'CDH5-CDH5', 'CLEC2B-KLRB1', 'CD69-KLRB1', 'NFASC-CNTN1', 'NFASC-CNTNAP1', 'CNTN1-NRCAM', 'EFNA3-EPHA1', 'EFNA3-EPHA2', 'EFNA3-EPHA3', 'EFNA3-EPHA4', 'EFNA5-EPHA1', 'EFNA5-EPHA2', 'EFNA5-EPHA3', 'EFNA5-EPHA4', 'ICAM1-ITGAX', 'ICAM1-ITGB2', 'ICAM2-ITGB2', 'ICAM1-ITGAM', 'ICAM2-ITGAM', 'ICAM1-SPN', 'ICOSLG-ICOS', 'ICOSLG-CD28', 'ICOSLG-CTLA4', 'ITGB2-CD226', 'ITGB2-ICAM1', 'ITGB2-ICAM2', 'JAM3-ITGAM', 'JAM3- ...

# %%
# create cell x gene matrix
ct_masks = {ct: adata.obs['cell_type'] == ct for ct in adata.obs['cell_type'].unique()}

df = pd.DataFrame(index=adata.obs_names, columns=genes)
df = df.fillna(0)

for name in tqdm(interactions.keys(), total=len(interactions)):
    lig, rec = name.rsplit('-', 1)
    
    tmp = interactions[name].sum(axis=1)
    for ct, val in zip(interactions[name].index, tmp):
        df.loc[ct_masks[ct], lig] += tmp[ct]
    
    tmp = interactions[name].sum(axis=0)
    for ct, val in zip(interactions[name].columns, tmp):
        df.loc[ct_masks[ct], rec] += tmp[ct]

df.shape
# Out:
# 100%|██████████| 310/310 [00:14<00:00, 22.12it/s]
# (5778, 958)

# %%
print('Number of LR filtered using celltype specificity:')
np.where(df > 0, 1, 0).sum().sum() / (df.shape[0] * df.shape[1])
# Out:
# Number of LR filtered using celltype specificity:
# 0.1520613788822479

# %%
# df.to_parquet('/ix/djishnu/shared/djishnu_kor11/miscellaneous/tonsil_commot_LRs.parquet')
df.to_parquet('/ix/djishnu/shared/djishnu_kor11/commot_outputs/tonsil_LRs.parquet')

# %%
ligands = ['IL2', 'IL7']
df[ligands].sum(axis=0)
# Out:
# IL2    0.000000
# IL7    2.603589
# dtype: float64

# %% [markdown]
# ### Get ligand receivers mask for tissue density weighting

# %%
df = pd.read_parquet('/ix/djishnu/shared/djishnu_kor11/commot_outputs/tonsil_LRs.parquet')
df.head(3)
# Out:
#                     BTC  PENK  CLDN11  FGFR1  CHRNA5  IL11  PRSS1  SEMA5A  \
# NAME
# AAACCCAAGCGCCTTG-1    0     0       0      0       0     0      0       0
# AAACCCAAGTGGACGT-1    0     0       0      0       0     0      0       0
# AAACCCACAGAAGTGC-1    0     0       0      0       0     0      0       0
#
#                     PDGFC  PTPRF  ...  ANGPTL7  OPRK1  COL2A1  IFNE      CCL4  \
# NAME                              ...
# AAACCCAAGCGCCTTG-1      0      0  ...        0      0       0     0  0.000054
# AAACCCAAGTGGACGT-1      0      0  ...        0      0       0     0  0.000011
# AAACCCACAGAAGTGC-1      0      0  ...        0      0       0     0  0.000000
#
#                     PRSS2  AMH  PRLR     EPHA2  POMC
# NAME
# AAACCCAAGCGCCTTG-1      0    0     0  0.000000     0
# AAACCCAAGTGGACGT-1      0    0     0  0.000009     0
# AAACCCACAGAAGTGC-1      0    0     0  0.000000     0
#
# [3 rows x 958 columns]

# %%
expanded.head(3)
# Out:
#    ligand receptor pathway           signaling               name      rename
# 38   GDF7    BMPR2     BMP  Secreted Signaling  GDF7-BMPR1A_BMPR2  GDF7-BMPR2
# 41   GDF7    BMPR2     BMP  Secreted Signaling  GDF7-BMPR1B_BMPR2  GDF7-BMPR2
# 54   BMP6    BMPR2     BMP  Secreted Signaling   BMP6-ACVR1_BMPR2  BMP6-BMPR2

# %%
info.keys()
# Out:
# dict_keys(['GDF7-BMPR2', 'BMP6-BMPR2', 'BMP7-BMPR2', 'BMP8A-BMPR2', 'WNT10A-LRP5', 'WNT10A-FZD7', 'WNT10A-FZD8', 'WNT10B-LRP5', 'WNT10B-FZD7', 'WNT10B-FZD8', 'WNT3-LRP5', 'WNT3-FZD7', 'WNT3-FZD8', 'WNT4-LRP5', 'WNT4-FZD7', 'WNT4-FZD8', 'WNT5B-FZD7', 'WNT5B-FZD8', 'NRG1-ERBB4', 'NRG2-ERBB4', 'NRG3-ERBB4', 'FGF7-FGFR2', 'PDGFD-PDGFRB', 'VEGFC-FLT4', 'VEGFC-KDR', 'IGF1-IGF1R', 'IGF1-ITGA6', 'CCL2-CCR2', 'CCL4-CCR5', 'CCL5-CCR5', 'CCL3-CCR5', 'CCL20-CCR6', 'CCL19-CCR7', 'CCL21-CCR7', 'CXCL9-CXCR3', 'CXCL10-CXCR3', 'CXCL13-CXCR3', 'CXCL12-CXCR4', 'CXCL13-CXCR5', 'CXCL16-CXCR6', 'IL4-IL4R', 'IL7-IL7R', 'IL15-IL2RB', 'IL4-IL13RA1', 'IL6-IL6R', 'IL6-IL6ST', 'EBI3-IL27RA', 'EBI3-IL6ST', 'IL18-IL18R1', 'IL18-IL18RAP', 'IL33-IL1RAP', 'IL34-CSF1R', 'CSF1-CSF1R', 'TNF-TNFRSF1A', 'TNF-TNFRSF1B', 'EDA-EDAR', 'TNFSF11-TNFRSF11A', 'TNFSF8-TNFRSF8', 'TNFSF9-TNFRSF9', 'TNFSF13B-TNFRSF13B', 'CD40LG-ITGA2B', 'CD40LG-ITGA5', 'CD40LG-ITGB1', 'CD40LG-ITGAM', 'CD40LG-ITGB2', 'ANGPTL1-ITGA1', 'ANGPTL1-ITGB1', 'C3-CR2', 'C3-ITGAM', 'C3-ITGB2', 'C3-ITGAX', 'TAC4-TACR1', 'GZMA-F2R', 'GZMA-PARD3', 'NPPC-NPR2', 'KITLG-KIT', 'FLT3LG-FLT3', 'SEMA3A-NRP1', 'SEMA3A-PLXNA4', 'SEMA3C-NRP1', 'SEMA3C-PLXNA4', 'SEMA3D-NRP1', 'SEMA3D-PLXNA4', 'SEMA3C-NRP2', 'SEMA3D-NRP2', 'SEMA3C-PLXND1', 'ANXA1-FPR1', 'GAS6-AXL', 'GAS6-MERTK', 'RARRES2-GPR1', 'RARRES2-CMKLR1', 'COL1A1-ITGA1', 'COL1A1-ITGB1', 'COL1A2-ITGA1', 'COL1A2-ITGB1', 'COL4A1-ITGA1', 'COL4A1-ITGB1', 'COL4A3-ITGA1', 'COL4A3-ITGB1', 'COL4A4-ITGA1', 'COL4A4-ITGB1', 'COL6A1-ITGA1', 'COL6A1-ITGB1', 'COL6A2-ITGA1', 'COL6A2-ITGB1', 'COL6A3-ITGA1', 'COL6A3-ITGB1', 'COL6A6-ITGA1', 'COL6A6-ITGB1', 'COL9A2-ITGA1', 'COL9A2-ITGB1', 'FN1-ITGB1', 'FN1-ITGA4', 'FN1-ITGA5', 'FN1-ITGA8', 'LAMA3-ITGA1', 'LAMA3-ITGB1', 'LAMA4-ITGA1', 'LAMA4-ITGB1', 'LAMC1-ITGA1', 'LAMC1-ITGB1', 'CHAD-ITGB1', 'RELN-ITGB1', 'THBS2-ITGB1', 'LAMA3-ITGA6', 'LAMA4-ITGA6', 'LAMC1-ITGA6', 'TNC-ITGA8', 'TNC-ITGB1', 'TNR-ITGA8', 'TNR-ITGB1', 'FRAS1-ITGA8', 'FRAS1-ITGB1', 'FREM1-ITGA8', 'FREM1-ITGB1', 'TNC-ITGA9', 'TNR-ITGA9', 'COL1A1-ITGA9', 'COL1A2-ITGA9', 'COL4A1-ITGA9', 'COL4A3-ITGA9', 'COL4A4-ITGA9', 'COL6A1-ITGA9', 'COL6A2-ITGA9', 'COL6A3-ITGA9', 'COL6A6-ITGA9', 'COL9A2-ITGA9', 'LAMA3-ITGA9', 'LAMA4-ITGA9', 'LAMC1-ITGA9', 'COL1A1-ITGA10', 'COL1A2-ITGA10', 'COL4A1-ITGA10', 'COL4A3-ITGA10', 'COL4A4-ITGA10', 'COL6A1-ITGA10', 'COL6A2-ITGA10', 'COL6A3-ITGA10', 'COL6A6-ITGA10', 'COL9A2-ITGA10', 'FN1-ITGB7', 'FN1-ITGA2B', 'TNC-ITGA2B', 'TNR-ITGA2B', 'FN1-ITGB8', 'LAMA3-ITGB8', 'LAMA4-ITGB8', 'LAMC1-ITGB8', 'COL1A1-ITGB8', 'COL1A2-ITGB8', 'COL4A1-ITGB8', 'COL4A3-ITGB8', 'COL4A4-ITGB8', 'COL6A1-ITGB8', 'COL6A2-ITGB8', 'COL6A3-ITGB8', 'COL6A6-ITGB8', 'COL9A2-ITGB8', 'FN1-CD44', 'COL1A1-CD44', 'COL1A2-CD44', 'COL4A1-CD44', 'COL4A3-CD44', 'COL4A4-CD44', 'COL6A1-CD44', 'COL6A2-CD44', 'COL6A3-CD44', 'COL6A6-CD44', 'COL9A2-CD44', 'LAMA3-CD44', 'LAMA4-CD44', 'LAMC1-CD44', 'COL1A1-SDC4', 'COL1A2-SDC4', 'COL4A1-SDC4', 'COL4A3-SDC4', 'COL4A4-SDC4', 'COL6A1-SDC4', 'COL6A2-SDC4', 'COL6A3-SDC4', 'COL6A6-SDC4', 'COL9A2-SDC4', 'FN1-SDC4', 'TNC-SDC4', 'TNR-SDC4', 'THBS2-SDC4', 'LAMA3-SV2A', 'LAMA4-SV2A', 'LAMC1-SV2A', 'THBS2-CD36', 'COL1A1-GP6', 'COL1A2-GP6', 'COL4A1-GP6', 'COL4A3-GP6', 'COL4A4-GP6', 'COL6A1-GP6', 'COL6A2-GP6', 'COL6A3-GP6', 'COL6A6-GP6', 'COL9A2-GP6', 'ADGRE5-CD55', 'ALCAM-CD6', 'ANXA1-FPR3', 'CADM1-CADM1', 'CD226-NECTIN2', 'CD226-PVR', 'FCER2-ITGAM', 'FCER2-ITGB2', 'FCER2-ITGAX', 'FCER2-CR2', 'ENTPD1-TMIGD3', 'CD40LG-CD40', 'CD6-ALCAM', 'CD80-CD274', 'CD80-CD28', 'CD80-CTLA4', 'CD86-CD28', 'CD86-CTLA4', 'CD96-NECTIN1', 'CD96-PVR', 'CDH4-CDH4', 'CDH2-CDH2', 'CDH5-CDH5', 'CLEC2B-KLRB1', 'CD69-KLRB1', 'NFASC-CNTN1', 'NFASC-CNTNAP1', 'CNTN1-NRCAM', 'EFNA3-EPHA1', 'EFNA3-EPHA2', 'EFNA3-EPHA3', 'EFNA3-EPHA4', 'EFNA5-EPHA1', 'EFNA5-EPHA2', 'EFNA5-EPHA3', 'EFNA5-EPHA4', 'ICAM1-ITGAX', 'ICAM1-ITGB2', 'ICAM2-ITGB2', 'ICAM1-ITGAM', 'ICAM2-ITGAM', 'ICAM1-SPN', 'ICOSLG-ICOS', 'ICOSLG-CD28', 'ICOSLG-CTLA4', 'ITGB2-CD226', 'ITGB2-ICAM1', 'ITGB2-ICAM2', 'JAM3-ITGAM', 'JAM3- ...

# %%
[x for x in info.keys() if 'IL7' in x]
# Out:
# ['IL7-IL7R']

# %%
ligand_receivers_mask = pd.DataFrame(index=df.index, columns=np.unique(expanded.ligand)).fillna(0)

for _, row in tqdm(expanded.iterrows(), total=len(expanded)):
    ligand = row.ligand
    receptor = row.receptor

    receivers = df[receptor].values
    ligand_receivers_mask.loc[:, ligand] += receivers

ligand_receivers_mask.head(3)
# Out:
# 100%|██████████| 473/473 [00:00<00:00, 1122.55it/s]
#                       ADGRE5     ALCAM   ANGPTL1     ANXA1      BMP6  \
# NAME
# AAACCCAAGCGCCTTG-1  0.000224  0.002991  0.002544  0.000000  0.000351
# AAACCCAAGTGGACGT-1  0.000251  0.000528  0.001493  0.000002  0.000554
# AAACCCACAGAAGTGC-1  0.000059  0.000000  0.001402  0.000000  0.000254
#
#                         BMP7     BMP8A        C3     CADM1     CCL19  ...  \
# NAME                                                                  ...
# AAACCCAAGCGCCTTG-1  0.000351  0.000351  0.002458  0.000014  0.000485  ...
# AAACCCAAGTGGACGT-1  0.000554  0.000554  0.001567  0.001478  0.000015  ...
# AAACCCACAGAAGTGC-1  0.000254  0.000254  0.001281  0.000044  0.000000  ...
#
#                       TNFSF8    TNFSF9       TNR     VEGFC      VSIR  \
# NAME
# AAACCCAAGCGCCTTG-1  0.000007  0.000011  0.002058  0.000031  0.000047
# AAACCCAAGTGGACGT-1  0.000000  0.000002  0.003399  0.000000  0.000068
# AAACCCACAGAAGTGC-1  0.000032  0.000000  0.002826  0.000000  0.000013
#
#                       WNT10A    WNT10B      WNT3      WNT4     WNT5B
# NAME
# AAACCCAAGCGCCTTG-1  0.000122  0.000122  0.000122  0.000122  0.000000
# AAACCCAAGTGGACGT-1  0.000524  0.000524  0.000524  0.000524  0.000051
# AAACCCACAGAAGTGC-1  0.000319  0.000319  0.000319  0.000319  0.000001
#
# [3 rows x 126 columns]

# %%
ligand_receivers_mask.to_parquet('/ix/djishnu/shared/djishnu_kor11/commot_outputs/tonsil_ligreceivers.parquet')

# %% [markdown]
# ### Get true LR pairs

# %%
stop

# %%
genes = set(df_ligrec.ligand) | set(df_ligrec.receptor)
genes = list(genes)
len(genes)
# Out:
# 199

# %%
def get_sig_interactions(value_matrix, p_matrix, pval=0.05):
    p_matrix = np.where(p_matrix < pval, 1, 0)
    return value_matrix * p_matrix

interactions = {}
for lig, rec in tqdm(zip(df_ligrec['ligand'], df_ligrec['receptor'])):
    name = lig + '-' + rec

    if name in info.keys():

        value_matrix = info[name]['communication_matrix']
        p_matrix = info[name]['communication_pvalue']

        sig_matrix = get_sig_interactions(value_matrix, p_matrix)
        
        if sig_matrix.sum().sum() > 0:
            interactions[name] = sig_matrix
    
len(interactions)
# Out:
# 238it [00:00, 1703.08it/s]
# 238

# %%
# create cell x LR unit matrix
ct_masks = {ct: adata.obs['cell_type'] == ct for ct in adata.obs['cell_type'].unique()}

df = pd.DataFrame(index=adata.obs_names, columns=genes)
df = df.fillna(0)

for lig, rec in tqdm(zip(df_ligrec.ligand, df_ligrec.receptor), total=len(df_ligrec)):

    tmp = interactions[name].sum(axis=1)
    for ct, val in zip(interactions[name].index, tmp):
        df.loc[ct_masks[ct], lig] += tmp[ct]
    
    tmp = interactions[name].sum(axis=0)
    for ct, val in zip(interactions[name].columns, tmp):
        df.loc[ct_masks[ct], rec] += tmp[ct]

df.shape
# Out:
# 100%|██████████| 238/238 [00:06<00:00, 39.04it/s]
# (5778, 199)

# %%
print('Number of LR filtered using celltype specificity:')
np.where(df > 0, 1, 0).sum().sum() / (df.shape[0] * df.shape[1])
# Out:
# Number of LR filtered using celltype specificity:
# 0.1520613788822479

# %%
# df.to_parquet('/ix/djishnu/shared/djishnu_kor11/miscellaneous/tonsil_commot_LRs_units.parquet')
df.to_parquet('/ix/djishnu/shared/djishnu_kor11/commot_outputs/tonsil_LRs_units.parquet')

# %% [markdown]
# ### Scratch

# %%
# def count_interactions(matrix):
#     mask = matrix.astype(bool).toarray()
#     mask = np.maximum(mask, mask.T)
#     mask = np.triu(mask, k=1)
#     return mask.sum()

def count_interactions(matrix):
    return matrix.sum()

num_values = {k: count_interactions(lr_info[k]) for k in lr_info.keys()}

# %%
# import matplotlib.pyplot as plt

# plt.hist(list(num_values.values()), bins=1000)
# plt.semilogy()

# # threshold = round(adata.n_obs * 0.05)
# threshold = np.percentile(list(num_values.values()), 10)

# plt.text(threshold, plt.ylim()[1] * 0.9, f'Threshold: {threshold}', color='red', ha='center')
# plt.axvline(threshold, color='red', linestyle='dashed', linewidth=1)
# plt.axvspan(0, threshold, color='red', alpha=0.3)
# plt.xlim(0, 20000)
# plt.xlabel('Number of interactions')

# plt.show()

# %%
from collections import defaultdict

celltypes = adata.obs['cell_type'].unique()
interactions = defaultdict(lambda: defaultdict(dict))

for a in celltypes:
    a_mask = adata.obs['cell_type'] == a
    
    for b in celltypes:
        b_mask = adata.obs['cell_type'] == b
        
        for k, v in lr_info.items():
            if k == 'total=total':
                continue

            
            interactions[a][b][k]=np.sum(v[a_mask, :][:, b_mask].astype(bool))

len(interactions)
# Out:
# 9

# %%
interactions
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'T cells': defaultdict(dict,
#                          {'T cells': {'ADGRE5-CD55': 887,
#                            'ALCAM-CD6': 1694,
#                            'ANGPTL1-ITGA1_ITGB1': 41,
#                            'ANXA1-FPR1': 4,
#                            'C3-CR2': 7,
#                            'C3-ITGAM_ITGB2': 1,
#                            'C3-ITGAX_ITGB2': 0,
#                            'CADM1-CADM1': 40,
#                            'CCL19-CCR7': 63,
#                            'CCL2-CCR2': 0,
#                            'CCL20-CCR6': 26,
#                            'CCL21-CCR7': 206,
#                            'CCL3-CCR5': 0,
#                            'CCL4-CCR5': 27,
#                            'CCL5-CCR5': 175,
#                            'CD226-NECTIN2': 0,
#                            'CD226-PVR': 61,
#                            'CD274-PDCD1': 27,
#                            'CD40LG-CD40': 12,
#                            'CD40LG-ITGA5_ITGB1': 173,
#                            'CD40LG-ITGAM_ITGB2': 5,
#                            'CD6-ALCAM': 1694,
#                            'CD69-KLRB1': 562,
#                            'CD80-CD274': 7,
#                            'CD80-CD28': 200,
#                            'CD80-CTLA4': 43,
#                            'CD86-CD28': 108,
#                            'CD86-CTLA4': 25,
#                            'CD96-NECTIN1': 132,
#                            'CD96-PVR': 131,
#                            'CDH2-CDH2': 1,
#                            'CDH4-CDH4': 145,
#                            'CDH5-CDH5': 0,
#                            'CLEC2B-KLRB1': 407,
#                            'CNTN1-NRCAM': 1,
#                            'COL1A1-CD44': 0,
#                            'COL1A1-GP6': 0,
#                            'COL1A1-ITGA10_ITGB1': 0,
#                            'COL1A1-ITGA1_ITGB1': 0,
#                            'COL1A1-ITGA9_ITGB1': 0,
#                            'COL1A1-SDC4': 0,
#                            'COL1A2-CD44': 73,
#                            'COL1A2-GP6': 8,
#                            'COL1A2-ITGA10_ITGB1': 2,
#                            'COL1A2-ITGA1_ITGB1': 3,
#                            'COL1A2-ITGA9_ITGB1': 0,
#                            'COL1A2-SDC4': 0,
#                            'COL4A1-CD44': 0,
#                            'COL4A1-GP6': 0,
#                            'COL4A1-ITGA10_ITGB1': 0,
#                            'COL4A1-ITGA1_ITGB1': 0,
#                            'COL4A1-ITGA9_ITGB1': 0,
#                            'COL4A1-SDC4': 0,
#                            'COL4A3-CD44': 519,
#                            'COL4A3-GP6': 58,
#                            'COL4A3-ITGA10_ITGB1': 14,
#                            'COL4A3-ITGA1_ITGB1': 16,
#                            'COL4A3-ITGA9_ITGB1': 0,
#                            'COL4A3-SDC4': 1,
#                            'COL4A4-CD44': 311,
#                            'COL4A4-GP6': 21,
#                            'COL4A4-ITGA10_ITGB1': 6,
#                            'COL4A4-ITGA1_ITGB1': 14,
#                            'COL4A4-ITGA9_ITGB1': 0,
#                            'COL4A4-SDC4': 1,
#                            'COL6A1-CD44': 26,
#                            'COL6A1-GP6': 0,
#                            'COL6A1-ITGA10_ITGB1': 1,
#                            'COL6A1-ITGA1_ITGB1': 2,
#                            'COL6A1-ITGA9_ITGB1': 0,
#                            'COL6A1-SDC4': 0,
#                            'COL6A2-CD44': 148,
#                            'COL6A2-GP6': 13,
#                            'COL6A2-ITGA10_ITGB1': 5,
#                            'COL6A2-ITGA1_ITGB1': 2,
#                            'COL6A2-ITGA9_ITGB1': 0,
#                            'COL6A2-SDC4': 0,
#                            'COL6A3-CD44': 1173,
#                            'COL6A3-GP6': 122,
#                            'COL6A3-ITGA10_ITGB1': 26,
#                            'COL6A3-ITGA1_ITGB1': 41,
#                            'COL6A3-ITGA9_ITGB1': 0,
#                            'COL6A3-SDC4': 1,
#                            'COL6A6-CD44': 481,
#                            'COL6A6-GP6': 42,
#                            'COL6A6-ITGA10_ITGB1': 6,
#                            'COL6A6-ITGA1_ITGB1': 9,
#                            'COL6A6-ITGA9_ITGB1': 0,
#                            'COL6A6-SDC4': 0,
#                            'COL9A2-CD44': 85,
#                            'COL9A2-GP6': 9,
#                            'COL9A2-ITGA10_ITGB1': 1,
#                            'COL9A2-ITGA1_ITGB1': 4,
#                            'COL9A2-ITGA9_ITGB1': 0,
#                            'COL9A2-SDC4': 0,
#                            'CSF1-CSF1R': 0,
#                            'CXCL10-CXCR3': 0,
#                            'CXCL12-CXCR4': 7,
#                            'CXCL13-CXCR3': 2,
#                            'CXCL13-CXCR5': 21,
#                            'CXCL16-CXCR6': 0,
#                            'CXCL9-CXCR3': 1,
#                            'DLL4-NOTCH1': 0,
#                            'EDA-EDAR': 67,
#                            'EFNA3-EPHA1': 0,
#                            'EFNA3-EPHA2': 0,
#                            'EFNA3-EPHA3': 0,
#                            'EFNA3-EPHA4': 0,
#                            'EFNA5-EPHA1': 2,
#                            'EFNA5-EPHA2': 0,
#                            'EFNA5-EPHA3': 0,
#                            'EFNA5-EPHA4': 6,
#                            'ENTPD1-TMIGD3': 2,
#                            'FCER2-CR2': 13,
#                            'FCER2-ITGAM_ITGB2': 0,
#                            'FCER2-ITGAX_ITGB2': 0,
#                            'FGF7-FGFR2': 0,
#                            'FLT3LG-FLT3': 27,
#                            'FN1-CD44': 477,
#                            'FN1-ITGA4_ITGB1': 109,
#                            'FN1-ITGA4_ITGB7': 16,
#                            'FN1-ITGA5_ITGB1': 25,
#                            'FN1-ITGA8_ITGB1': 0,
#                            'FN1-SDC4': 0,
#                            'GAS6-AXL': 0,
#                            'GAS6-MERTK': 9,
#                            'GZMA-F2R': 160,
#                            'GZMA-PARD3': 73,
#                            'HLA-G-CD8A': 2,
#                            'HLA-G-CD8B': 1,
#                            'HLA-G-LILRB2': 0,
#                            'ICAM1-ITGAM_ITGB2': 2,
#                            'ICAM1-ITGAX_ITGB2': 0,
#                            'ICAM1-SPN': 92,
#                            'ICAM2-ITGAM_ITGB2': 3,
#                            'ICOSLG-CD28': 110,
#                            'ICOSLG-CTLA4': 19,
#                            'ICOSLG-ICOS': 78,
#                            'IGF1-IGF1R': 0,
#                            'IL18-IL18R1_IL18RAP': 3,
#                            'IL34-CSF1R': 0,
#                            'IL4-IL4R': 11,
#                            'IL4-IL4R_IL13RA1': 0,
#                            'IL6-IL6R_IL6ST': 0,
#                            'ITGA4_ITGB1-VCAM1': 41,
#                            'ITGA4_ITGB7-VCAM1': 8,
#                            'ITGA9_ITGB1-VCAM1': 0,
#                            'ITGB2-CD226': 1461,
#                            'ITGB2-ICAM1': 123,
#                            'ITGB2-ICAM2': 491,
#                            'JAM3-ITGAM_ITGB2': 1,
#                            'JAM3-JAM3': 87,
#                            'KITLG-KIT': 0,
#                            'LAMA3-CD44': 60,
#                            'LAMA3-ITGA1_ITGB1': 4,
#                            'LAMA3-ITGA6_ITGB1': 4,
#                            'LAMA3-ITGA9_ITGB1': 0,
#                            'LAMA3-SV2A': 0,
#                            'LAMA4-CD44': 14,
#                            'LAMA4-ITGA1_ITGB1': 2,
#                            'LAMA4-ITGA6_ITGB1': 1,
#                            'LAMA4-ITGA9_ITGB1': 0,
#                            'LAMA4-SV2A': 0,
#                            'LAMC1-CD44': 35,
#                            'LAMC1-ITGA1_ITGB1': 1,
#                            'LAMC1-ITGA6_ITGB1': 1,
#                            'LAMC1-ITGA9_ITGB1': 0,
#                            'LAMC1-SV2A': 0,
#                            'LCK-CD8A_CD8B': 258,
#                            'NCAM1-NCAM1': 10,
#                            'NCAM1-NCAM2': 2,
#                            'NECTIN1-CD96': 132,
#                            'NECTIN1-NECTIN3': 10,
#                            'NECTIN2-CD226': 0,
#                            'NECTIN2-TIGIT': 0,
#                            'NECTIN3-NECTIN1': 10,
#                            'NECTIN3-NECTIN2': 0,
#                            'NECTIN3-PVR': 10,
#                            'NECTIN3-TIGIT': 191,
#                            'NEGR1-NEGR1': 4,
#                            'NFASC-CNTN1_CNTNAP1': 0,
#                            'NPPC-NPR2': 0,
#                            'NRG1-ERBB4': 0,
#                            'NRG2-ERBB4': 0,
#                            'NRG3-ERBB4': 0,
#                            'NRXN1-NLGN1': 0,
#                            'NRXN1-NLGN3': 0,
#                            'NRXN3-NLGN1': 0,
#                            'NRXN3-NLGN3': 6,
#                            'PDCD1LG2-PDCD1': 16,
#                            'PDGFD-PDGFRB': 0,
#                            'PECAM1-PECAM1': 691,
#                            'PTPRM-PTPRM': 1364,
#                            'PVR-CD226': 61,
#                            'PVR-TIGIT': 33,
#                            'RARRES2-CMKLR1': 1,
#                            'RARRES2-GPR1': 0,
#                            'SELPLG-SELL': 840,
#                            'SELPLG-SELP': 5,
#                            'SEMA3A-NRP1_PLXNA4': 1,
#                            'SEMA3C-NRP1_NRP2_PLXND1': 0,
#                            'SEMA3C-NRP1_PLXNA4': 1,
#                            'SEMA3C-NRP2_PLXNA4': 0,
#                            'SEMA3C-PLXND1': 4,
#                            'SEMA3D-NRP1_PLXNA4': 0,
#                            'SEMA3D-NRP2_PLXNA4': 0,
#                            'SEMA6A-PLXNA4': 25,
#                            'TAC4-TACR1': 82,
#                            'THBS2-CD36': 0,
#                            'THBS2-SDC4': 0,
#                            'TIGIT-NECTIN2': 0,
#                            'TIGIT-PVR': 33,
#                            'TNC-ITGA8_ITGB1': 0,
#                            'TNC-ITGA9_ITGB1': 0,
#                            'TNC-SDC4': 0,
#                            'TNF-TNFRSF1A': 49,
#                            'TNF-TNFRSF1B': 119,
#                            'TNFSF11-TNFRSF11A': 1,
#                            'TNFSF13B-TNFRSF13B': 24,
#                            'TNFSF8-TNFRSF8': 31,
#                            'TNFSF9-TNFRSF9': 1,
#                            'TNR-ITGA8_ITGB1': 0,
#                            'TNR-ITGA9_ITGB1': 0,
#                            'TNR-SDC4': 1,
#                            'VEGFC-FLT4': 0,
#                            'VEGFC-FLT4_KDR': 0,
#                            'VEGFC-KDR': 0,
#                            'VSIR-IGSF11': 114,
#                            'WNT10A-FZD7_LRP5': 0,
#                            'WNT10A-FZD8_LRP5': 0,
#                            'WNT10B-FZD7_LRP5': 0,
#                            'WNT10B-FZD8_LRP5': 0,
#                            'WNT3-FZD7_LRP5': 0,
#                            'WNT3-FZD8_LRP5': 0,
#                            'WNT4-FZD7_LRP5': 0,
#                            'WNT4-FZD8_LRP5': 0,
#                            'WNT5B-FZD7': 0,
#                            'WNT5B-FZD8': 0,
#                            'total-total': 10110},
#                           'Plasma': {'ADGRE5-CD55': 343,
#                            'ALCAM-CD6': 257,
#                            'ANGPTL1-ITGA1_ITGB1': 12,
#                            'ANXA1-FPR1': 1,
#                            'C3-CR2': 30,
#                            'C3-ITGAM_ITGB2': 0,
#                            'C3-ITGAX_ITGB2': 0,
#                            'CADM1-CADM1': 75,
#                            'CCL19-CCR7': 6,
#                            'CCL2-CCR2': 0,
#                            'CCL20-CCR6': 4,
#                            'CCL21-CCR7': 13,
#                            'CCL3-CCR5': 0,
#                            'CCL4-CCR5': 1,
#                            'CCL5-CCR5': 0,
#                            'CD226-NECTIN2': 14,
#                            'CD226-PVR': 16,
#                            'CD274-PDCD1': 10,
#                            'CD40LG-CD40': 388,
#                            'CD40LG-ITGA5_ITGB1': 19,
#                            'CD40LG-ITGAM_ITGB2': 8,
#                            'CD6-ALCAM': 2132,
#                            'CD69-KLRB1': 226,
#                            'CD80-CD274': 3,
#                            'CD80-CD28': 17,
#                            'CD80-CTLA4': 1,
#                            'CD86-CD28': 12,
#                            'CD86-CTLA4': 4,
#                            'CD96-NECTIN1': 54,
#                            'CD96-PVR': 52,
#                            'CDH2-CDH2': 0,
#                            'CDH4-CDH4': 7,
#                            'CDH5-CDH5': 0,
#                            'CLEC2B-KLRB1': 164,
#                            'CNTN1-NRCAM': 0,
#                            'COL1A1-CD44': 0,
#                            'COL1A1-GP6': 0,
#                            'COL1A1-ITGA10_ITGB1': 0,
#                            'COL1A1-ITGA1_ITGB1': 0,
#                            'COL1A1-ITGA9_ITGB1': 0,
#                            'COL1A1-SDC4': 0,
#                            'COL1A2-CD44': 6,
#                            'COL1A2-GP6': 0,
#                            'COL1A2-ITGA10_ITGB1': 0,
#                            'COL1A2-ITGA1_ITGB1': 0,
#                            'COL1A2-ITGA9_ITGB1': 0,
#                            'COL1A2-SDC4': 0,
#                            'COL4A1-CD44': 0,
#                            'COL4A1-GP6': 0,
#                            'COL4A1-ITGA10_ITGB1': 0,
#                            'COL4A1-ITGA1_ITGB1': 0,
#                            'COL4A1-ITGA9_ITGB1': 0,
#                            'COL4A1-SDC4': 0,
#                            'COL4A3-CD44': 104,
#                            'COL4A3-GP6': 13,
#                            'COL4A3-ITGA10_ITGB1': 9,
#                            'COL4A3-ITGA1_ITGB1': 5,
#                            'COL4A3-ITGA9_ITGB1': 2,
#                            'COL4A3-SDC4': 14,
#                            'COL4A4-CD44': 80,
#                            'COL4A4-GP6': 14,
#                            'COL4A4-ITGA10_ITGB1': 5,
#                            'COL4A4-ITGA1_ITGB1': 4,
#                            'COL4A4-ITGA9_ITGB1': 3,
#                            'COL4A4-SDC4': 10,
#                            'COL6A1-CD44': 4,
#                            'COL6A1-GP6': 0,
#                            'COL6A1-ITGA10_ITGB1': 0,
#                            'COL6A1-ITGA1_ITGB1': 0,
#                            'COL6A1-ITGA9_ITGB1': 0,
#                            'COL6A1-SDC4': 0,
#                            'COL6A2-CD44': 21,
#                            'COL6A2-GP6': 3,
#                            'COL6A2-ITGA10_ITGB1': 0,
#                            'COL6A2-ITGA1_ITGB1': 0,
#                            'COL6A2-ITGA9_ITGB1': 1,
#                            'COL6A2-SDC4': 1,
#                            'COL6A3-CD44': 128,
#                            'COL6A3-GP6': 6,
#                            'COL6A3-ITGA10_ITGB1': 13,
#                            'COL6A3-ITGA1_ITGB1': 6,
#                            'COL6A3-ITGA9_ITGB1': 2,
#                            'COL6A3-SDC4': 11,
#                            'COL6A6-CD44': 74,
#                            'COL6A6-GP6': 10,
#                            'COL6A6-ITGA10_ITGB1': 11,
#                            'COL6A6-ITGA1_ITGB1': 5,
#                            'COL6A6-ITGA9_ITGB1': 2,
#                            'COL6A6-SDC4': 9,
#                            'COL9A2-CD44': 10,
#                            'COL9A2-GP6': 0,
#                            'COL9A2-ITGA10_ITGB1': 0,
#                            'COL9A2-ITGA1_ITGB1': 0,
#                            'COL9A2-ITGA9_ITGB1': 1,
#                            'COL9A2-SDC4': 0,
#                            'CSF1-CSF1R': 0,
#                            'CXCL10-CXCR3': 0,
#                            'CXCL12-CXCR4': 5,
#                            'CXCL13-CXCR3': 0,
#                            'CXCL13-CXCR5': 4,
#                            'CXCL16-CXCR6': 0,
#                            'CXCL9-CXCR3': 0,
#                            'DLL4-NOTCH1': 0,
#                            'EDA-EDAR': 1,
#                            'EFNA3-EPHA1': 0,
#                            'EFNA3-EPHA2': 0,
#                            'EFNA3-EPHA3': 0,
#                            'EFNA3-EPHA4': 0,
#                            'EFNA5-EPHA1': 2,
#                            'EFNA5-EPHA2': 0,
#                            'EFNA5-EPHA3': 0,
#                            'EFNA5-EPHA4': 0,
#                            'ENTPD1-TMIGD3': 13,
#                            'FCER2-CR2': 29,
#                            'FCER2-ITGAM_ITGB2': 1,
#                            'FCER2-ITGAX_ITGB2': 2,
#                            'FGF7-FGFR2': 0,
#                            'FLT3LG-FLT3': 40,
#                            'FN1-CD44': 65,
#                            'FN1-ITGA4_ITGB1': 34,
#                            'FN1-ITGA4_ITGB7': 5,
#                            'FN1-ITGA5_ITGB1': 4,
#                            'FN1-ITGA8_ITGB1': 5,
#                            'FN1-SDC4': 5,
#                            'GAS6-AXL': 0,
#                            'GAS6-MERTK': 13,
#                            'GZMA-F2R': 8,
#                            'GZMA-PARD3': 69,
#                            'HLA-G-CD8A': 0,
#                            'HLA-G-CD8B': 0,
#                            'HLA-G-LILRB2': 0,
#                            'ICAM1-ITGAM_ITGB2': 0,
#                            'ICAM1-ITGAX_ITGB2': 1,
#                            'ICAM1-SPN': 15,
#                            'ICAM2-ITGAM_ITGB2': 3,
#                            'ICOSLG-CD28': 5,
#                            'ICOSLG-CTLA4': 0,
#                            'ICOSLG-ICOS': 8,
#                            'IGF1-IGF1R': 0,
#                            'IL18-IL18R1_IL18RAP': 0,
#                            'IL34-CSF1R': 0,
#                            'IL4-IL4R': 13,
#                            'IL4-IL4R_IL13RA1': 0,
#                            'IL6-IL6R_IL6ST': 0,
#                            'ITGA4_ITGB1-VCAM1': 85,
#                            'ITGA4_ITGB7-VCAM1': 6,
#                            'ITGA9_ITGB1-VCAM1': 0,
#                            'ITGB2-CD226': 266,
#                            'ITGB2-ICAM1': 138,
#                            'ITGB2-ICAM2': 238,
#                            'JAM3-ITGAM_ITGB2': 4,
#                            'JAM3-JAM3': 11,
#                            'KITLG-KIT': 0,
#                            'LAMA3-CD44': 4,
#                            'LAMA3-ITGA1_ITGB1': 0,
#                            'LAMA3-ITGA6_ITGB1': 2,
#                            'LAMA3-ITGA9_ITGB1': 0,
#                            'LAMA3-SV2A': 0,
#                            'LAMA4-CD44': 1,
#                            'LAMA4-ITGA1_ITGB1': 0,
#                            'LAMA4-ITGA6_ITGB1': 0,
#                            'LAMA4-ITGA9_ITGB1': 0,
#                            'LAMA4-SV2A': 0,
#                            'LAMC1-CD44': 10,
#                            'LAMC1-ITGA1_ITGB1': 0,
#                            'LAMC1-ITGA6_ITGB1': 2,
#                            'LAMC1-ITGA9_ITGB1': 0,
#                            'LAMC1-SV2A': 0,
#                            'LCK-CD8A_CD8B': 7,
#                            'NCAM1-NCAM1': 1,
#                            'NCAM1-NCAM2': 0,
#                            'NECTIN1-CD96': 21,
#                            'NECTIN1-NECTIN3': 1,
#                            'NECTIN2-CD226': 0,
#                            'NECTIN2-TIGIT': 0,
#                            'NECTIN3-NECTIN1': 4,
#                            'NECTIN3-NECTIN2': 2,
#                            'NECTIN3-PVR': 1,
#                            'NECTIN3-TIGIT': 35,
#                            'NEGR1-NEGR1': 1,
#                            'NFASC-CNTN1_CNTNAP1': 0,
#                            'NPPC-NPR2': 0,
#                            'NRG1-ERBB4': 0,
#                            'NRG2-ERBB4': 0,
#                            'NRG3-ERBB4': 0,
#                            'NRXN1-NLGN1': 0,
#                            'NRXN1-NLGN3': 0,
#                            'NRXN3-NLGN1': 0,
#                            'NRXN3-NLGN3': 1,
#                            'PDCD1LG2-PDCD1': 15,
#                            'PDGFD-PDGFRB': 1,
#                            'PECAM1-PECAM1': 272,
#                            'PTPRM-PTPRM': 180,
#                            'PVR-CD226': 11,
#                            'PVR-TIGIT': 12,
#                            'RARRES2-CMKLR1': 0,
#                            'RARRES2-GPR1': 0,
#                            'SELPLG-SELL': 50,
#                            'SELPLG-SELP': 0,
#                            'SEMA3A-NRP1_PLXNA4': 0,
#                            'SEMA3C-NRP1_NRP2_PLXND1': 0,
#                            'SEMA3C-NRP1_PLXNA4': 0,
#                            'SEMA3C-NRP2_PLXNA4': 0,
#                            'SEMA3C-PLXND1': 2,
#                            'SEMA3D-NRP1_PLXNA4': 0,
#                            'SEMA3D-NRP2_PLXNA4': 0,
#                            'SEMA6A-PLXNA4': 1,
#                            'TAC4-TACR1': 31,
#                            'THBS2-CD36': 0,
#                            'THBS2-SDC4': 0,
#                            'TIGIT-NECTIN2': 13,
#                            'TIGIT-PVR': 13,
#                            'TNC-ITGA8_ITGB1': 0,
#                            'TNC-ITGA9_ITGB1': 0,
#                            'TNC-SDC4': 0,
#                            'TNF-TNFRSF1A': 5,
#                            'TNF-TNFRSF1B': 29,
#                            'TNFSF11-TNFRSF11A': 0,
#                            'TNFSF13B-TNFRSF13B': 52,
#                            'TNFSF8-TNFRSF8': 9,
#                            'TNFSF9-TNFRSF9': 2,
#                            'TNR-ITGA8_ITGB1': 1,
#                            'TNR-ITGA9_ITGB1': 1,
#                            'TNR-SDC4': 4,
#                            'VEGFC-FLT4': 0,
#                            'VEGFC-FLT4_KDR': 0,
#                            'VEGFC-KDR': 0,
#                            'VSIR-IGSF11': 18,
#                            'WNT10A-FZD7_LRP5': 0,
#                            'WNT10A-FZD8_LRP5': 0,
#                            'WNT10B-FZD7_LRP5': 0,
#                            'WNT10B-FZD8_LRP5': 0,
#                            'WNT3-FZD7_LRP5': 0,
#                            'WNT3-FZD8_LRP5': 0,
#                            'WNT4-FZD7_LRP5': 0,
#                            'WNT4-FZD8_LRP5': 0,
#                            'WNT5B-FZD7': 1,
#                            'WNT5B-FZD8': 0,
#                            'total-total': 3616},
#                           'GC B': {'ADGRE5-CD55': 943,
#                            'ALCAM-CD6': 229,
#                            'ANGPTL1-ITGA1_ITGB1': 12,
#                            'ANXA1-FPR1': 0,
#                            'C3-CR2': 87,
#                            'C3-ITGAM_ITGB2': 2,
#                            'C3-ITGAX_ITGB2': 3,
#                            'CADM1-CADM1': 26,
#                            'CCL19-CCR7': 7,
#                            'CCL2-CCR2': 0,
#                            'CCL20-CCR6': 10,
#                            'CCL21-CCR7': 19,
#                            'CCL3-CCR5': 0,
#                            'CCL4-CCR5': 1,
#                            'CCL5-CCR5': 3,
#                            'CD226-NECTIN2': 33,
#                            'CD226-PVR': 8,
#                            'CD274-PDCD1': 6,
#                            'CD40LG-CD40': 1358,
#                            'CD40LG-ITGA5_ITGB1': 0,
#                            'CD40LG-ITGAM_ITGB2': 3,
#                            'CD6-ALCAM': 7159,
#                            'CD69-KLRB1': 471,
#                            'CD80-CD274': 6,
#                            'CD80-CD28': 5,
#                            'CD80-CTLA4': 0,
#                            'CD86-CD28': 7,
#                            'CD86-CTLA4': 0,
#                            'CD96-NECTIN1': 31,
#                            'CD96-PVR': 22,
#                            'CDH2-CDH2': 1,
#                            'CDH4-CDH4': 0,
#                            'CDH5-CDH5': 0,
#                            'CLEC2B-KLRB1': 404,
#                            'CNTN1-NRCAM': 0,
#                            'COL1A1-CD44': 0,
#                            'COL1A1-GP6': 0,
#                            'COL1A1-ITGA10_ITGB1': 0,
#                            'COL1A1-ITGA1_ITGB1': 0,
#                            'COL1A1-ITGA9_ITGB1': 0,
#                            'COL1A1-SDC4': 0,
#                            'COL1A2-CD44': 11,
#                            'COL1A2-GP6': 4,
#                            'COL1A2-ITGA10_ITGB1': 1,
#                            'COL1A2-ITGA1_ITGB1': 0,
#                            'COL1A2-ITGA9_ITGB1': 0,
#                            'COL1A2-SDC4': 1,
#                            'COL4A1-CD44': 0,
#                            'COL4A1-GP6': 0,
#                            'COL4A1-ITGA10_ITGB1': 0,
#                            'COL4A1-ITGA1_ITGB1': 0,
#                            'COL4A1-ITGA9_ITGB1': 0,
#                            'COL4A1-SDC4': 0,
#                            'COL4A3-CD44': 91,
#                            'COL4A3-GP6': 63,
#                            'COL4A3-ITGA10_ITGB1': 26,
#                            'COL4A3-ITGA1_ITGB1': 7,
#                            'COL4A3-ITGA9_ITGB1': 0,
#                            'COL4A3-SDC4': 4,
#                            'COL4A4-CD44': 77,
#                            'COL4A4-GP6': 47,
#                            'COL4A4-ITGA10_ITGB1': 19,
#                            'COL4A4-ITGA1_ITGB1': 5,
#                            'COL4A4-ITGA9_ITGB1': 0,
#                            'COL4A4-SDC4': 2,
#                            'COL6A1-CD44': 9,
#                            'COL6A1-GP6': 3,
#                            'COL6A1-ITGA10_ITGB1': 1,
#                            'COL6A1-ITGA1_ITGB1': 0,
#                            'COL6A1-ITGA9_ITGB1': 0,
#                            'COL6A1-SDC4': 1,
#                            'COL6A2-CD44': 23,
#                            'COL6A2-GP6': 2,
#                            'COL6A2-ITGA10_ITGB1': 11,
#                            'COL6A2-ITGA1_ITGB1': 0,
#                            'COL6A2-ITGA9_ITGB1': 0,
#                            'COL6A2-SDC4': 3,
#                            'COL6A3-CD44': 120,
#                            'COL6A3-GP6': 62,
#                            'COL6A3-ITGA10_ITGB1': 28,
#                            'COL6A3-ITGA1_ITGB1': 5,
#                            'COL6A3-ITGA9_ITGB1': 0,
#                            'COL6A3-SDC4': 8,
#                            'COL6A6-CD44': 77,
#                            'COL6A6-GP6': 41,
#                            'COL6A6-ITGA10_ITGB1': 25,
#                            'COL6A6-ITGA1_ITGB1': 5,
#                            'COL6A6-ITGA9_ITGB1': 1,
#                            'COL6A6-SDC4': 7,
#                            'COL9A2-CD44': 7,
#                            'COL9A2-GP6': 10,
#                            'COL9A2-ITGA10_ITGB1': 4,
#                            'COL9A2-ITGA1_ITGB1': 0,
#                            'COL9A2-ITGA9_ITGB1': 0,
#                            'COL9A2-SDC4': 1,
#                            'CSF1-CSF1R': 0,
#                            'CXCL10-CXCR3': 0,
#                            'CXCL12-CXCR4': 27,
#                            'CXCL13-CXCR3': 0,
#                            'CXCL13-CXCR5': 22,
#                            'CXCL16-CXCR6': 0,
#                            'CXCL9-CXCR3': 0,
#                            'DLL4-NOTCH1': 0,
#                            'EDA-EDAR': 0,
#                            'EFNA3-EPHA1': 0,
#                            'EFNA3-EPHA2': 0,
#                            'EFNA3-EPHA3': 0,
#                            'EFNA3-EPHA4': 0,
#                            'EFNA5-EPHA1': 0,
#                            'EFNA5-EPHA2': 0,
#                            'EFNA5-EPHA3': 0,
#                            'EFNA5-EPHA4': 3,
#                            'ENTPD1-TMIGD3': 18,
#                            'FCER2-CR2': 107,
#                            'FCER2-ITGAM_ITGB2': 0,
#                            'FCER2-ITGAX_ITGB2': 2,
#                            'FGF7-FGFR2': 0,
#                            'FLT3LG-FLT3': 39,
#                            'FN1-CD44': 65,
#                            'FN1-ITGA4_ITGB1': 103,
#                            'FN1-ITGA4_ITGB7': 7,
#                            'FN1-ITGA5_ITGB1': 0,
#                            'FN1-ITGA8_ITGB1': 0,
#                            'FN1-SDC4': 5,
#                            'GAS6-AXL': 0,
#                            'GAS6-MERTK': 4,
#                            'GZMA-F2R': 6,
#                            'GZMA-PARD3': 113,
#                            'HLA-G-CD8A': 0,
#                            'HLA-G-CD8B': 0,
#                            'HLA-G-LILRB2': 0,
#                            'ICAM1-ITGAM_ITGB2': 0,
#                            'ICAM1-ITGAX_ITGB2': 5,
#                            'ICAM1-SPN': 36,
#                            'ICAM2-ITGAM_ITGB2': 1,
#                            'ICOSLG-CD28': 3,
#                            'ICOSLG-CTLA4': 0,
#                            'ICOSLG-ICOS': 1,
#                            'IGF1-IGF1R': 0,
#                            'IL18-IL18R1_IL18RAP': 0,
#                            'IL34-CSF1R': 0,
#                            'IL4-IL4R': 135,
#                            'IL4-IL4R_IL13RA1': 0,
#                            'IL6-IL6R_IL6ST': 0,
#                            'ITGA4_ITGB1-VCAM1': 80,
#                            'ITGA4_ITGB7-VCAM1': 11,
#                            'ITGA9_ITGB1-VCAM1': 0,
#                            'ITGB2-CD226': 260,
#                            'ITGB2-ICAM1': 350,
#                            'ITGB2-ICAM2': 370,
#                            'JAM3-ITGAM_ITGB2': 1,
#                            'JAM3-JAM3': 25,
#                            'KITLG-KIT': 0,
#                            'LAMA3-CD44': 2,
#                            'LAMA3-ITGA1_ITGB1': 1,
#                            'LAMA3-ITGA6_ITGB1': 2,
#                            'LAMA3-ITGA9_ITGB1': 0,
#                            'LAMA3-SV2A': 1,
#                            'LAMA4-CD44': 0,
#                            'LAMA4-ITGA1_ITGB1': 0,
#                            'LAMA4-ITGA6_ITGB1': 0,
#                            'LAMA4-ITGA9_ITGB1': 0,
#                            'LAMA4-SV2A': 0,
#                            'LAMC1-CD44': 6,
#                            'LAMC1-ITGA1_ITGB1': 1,
#                            'LAMC1-ITGA6_ITGB1': 4,
#                            'LAMC1-ITGA9_ITGB1': 0,
#                            'LAMC1-SV2A': 1,
#                            'LCK-CD8A_CD8B': 0,
#                            'NCAM1-NCAM1': 0,
#                            'NCAM1-NCAM2': 0,
#                            'NECTIN1-CD96': 13,
#                            'NECTIN1-NECTIN3': 2,
#                            'NECTIN2-CD226': 0,
#                            'NECTIN2-TIGIT': 0,
#                            'NECTIN3-NECTIN1': 1,
#                            'NECTIN3-NECTIN2': 5,
#                            'NECTIN3-PVR': 0,
#                            'NECTIN3-TIGIT': 6,
#                            'NEGR1-NEGR1': 0,
#                            'NFASC-CNTN1_CNTNAP1': 0,
#                            'NPPC-NPR2': 0,
#                            'NRG1-ERBB4': 0,
#                            'NRG2-ERBB4': 0,
#                            'NRG3-ERBB4': 0,
#                            'NRXN1-NLGN1': 0,
#                            'NRXN1-NLGN3': 0,
#                            'NRXN3-NLGN1': 0,
#                            'NRXN3-NLGN3': 1,
#                            'PDCD1LG2-PDCD1': 5,
#                            'PDGFD-PDGFRB': 1,
#                            'PECAM1-PECAM1': 236,
#                            'PTPRM-PTPRM': 63,
#                            'PVR-CD226': 12,
#                            'PVR-TIGIT': 2,
#                            'RARRES2-CMKLR1': 0,
#                            'RARRES2-GPR1': 1,
#                            'SELPLG-SELL': 168,
#                            'SELPLG-SELP': 0,
#                            'SEMA3A-NRP1_PLXNA4': 0,
#                            'SEMA3C-NRP1_NRP2_PLXND1': 0,
#                            'SEMA3C-NRP1_PLXNA4': 0,
#                            'SEMA3C-NRP2_PLXNA4': 0,
#                            'SEMA3C-PLXND1': 1,
#                            'SEMA3D-NRP1_PLXNA4': 0,
#                            'SEMA3D-NRP2_PLXNA4': 0,
#                            'SEMA6A-PLXNA4': 1,
#                            'TAC4-TACR1': 108,
#                            'THBS2-CD36': 0,
#                            'THBS2-SDC4': 0,
#                            'TIGIT-NECTIN2': 15,
#                            'TIGIT-PVR': 5,
#                            'TNC-ITGA8_ITGB1': 0,
#                            'TNC-ITGA9_ITGB1': 0,
#                            'TNC-SDC4': 0,
#                            'TNF-TNFRSF1A': 1,
#                            'TNF-TNFRSF1B': 12,
#                            'TNFSF11-TNFRSF11A': 0,
#                            'TNFSF13B-TNFRSF13B': 58,
#                            'TNFSF8-TNFRSF8': 138,
#                            'TNFSF9-TNFRSF9': 0,
#                            'TNR-ITGA8_ITGB1': 0,
#                            'TNR-ITGA9_ITGB1': 0,
#                            'TNR-SDC4': 0,
#                            'VEGFC-FLT4': 0,
#                            'VEGFC-FLT4_KDR': 0,
#                            'VEGFC-KDR': 0,
#                            'VSIR-IGSF11': 59,
#                            'WNT10A-FZD7_LRP5': 0,
#                            'WNT10A-FZD8_LRP5': 0,
#                            'WNT10B-FZD7_LRP5': 0,
#                            'WNT10B-FZD8_LRP5': 0,
#                            'WNT3-FZD7_LRP5': 0,
#                            'WNT3-FZD8_LRP5': 0,
#                            'WNT4-FZD7_LRP5': 0,
#                            'WNT4-FZD8_LRP5': 0,
#                            'WNT5B-FZD7': 0,
#                            'WNT5B-FZD8': 0,
#                            'total-total': 9937},
#                           'DC': {'ADGRE5-CD55': 1087,
#                            'ALCAM-CD6': 547,
#                            'ANGPTL1-ITGA1_ITGB1': 85,
#                            'ANXA1-FPR1': 51,
#                            'C3-CR2': 31,
#                            'C3-ITGAM_ITGB2': 6,
#                            'C3-ITGAX_ITGB2': 17,
#                            'CADM1-CADM1': 77,
#                            'CCL19-CCR7': 32,
#                            'CCL2-CCR2': 0,
#                            'CCL20-CCR6': 66,
#                            'CCL21-CCR7': 89,
#                            'CCL3-CCR5': 0,
#                            'CCL4-CCR5': 19,
#                            'CCL5-CCR5': 141,
#                            'CD226-NECTIN2': 683,
#                            'CD226-PVR': 210,
#                            'CD274-PDCD1': 14,
#                            'CD40LG-CD40': 576,
#                            'CD40LG-ITGA5_ITGB1': 145,
#                            'CD40LG-ITGAM_ITGB2': 48,
#                            'CD6-ALCAM': 2931,
#                            'CD69-KLRB1': 393,
#                            'CD80-CD274': 22,
#                            'CD80-CD28': 47,
#                            'CD80-CTLA4': 4,
#                            'CD86-CD28': 18,
#                            'CD86-CTLA4': 4,
#                            'CD96-NECTIN1': 707,
#                            'CD96-PVR': 557,
#                            'CDH2-CDH2': 5,
#                            'CDH4-CDH4': 34,
#                            'CDH5-CDH5': 0,
#                            'CLEC2B-KLRB1': 277,
#                            'CNTN1-NRCAM': 1,
#                            'COL1A1-CD44': 0,
#                            'COL1A1-GP6': 0,
#                            'COL1A1-ITGA10_ITGB1': 0,
#                            'COL1A1-ITGA1_ITGB1': 0,
#                            'COL1A1-ITGA9_ITGB1': 0,
#                            'COL1A1-SDC4': 0,
#                            'COL1A2-CD44': 26,
#                            'COL1A2-GP6': 2,
#                            'COL1A2-ITGA10_ITGB1': 0,
#                            'COL1A2-ITGA1_ITGB1': 3,
#                            'COL1A2-ITGA9_ITGB1': 1,
#                            'COL1A2-SDC4': 4,
#                            'COL4A1-CD44': 0,
#                            'COL4A1-GP6': 0,
#                            'COL4A1-ITGA10_ITGB1': 0,
#                            'COL4A1-ITGA1_ITGB1': 0,
#                            'COL4A1-ITGA9_ITGB1': 0,
#                            'COL4A1-SDC4': 0,
#                            'COL4A3-CD44': 207,
#                            'COL4A3-GP6': 33,
#                            'COL4A3-ITGA10_ITGB1': 11,
#                            'COL4A3-ITGA1_ITGB1': 40,
#                            'COL4A3-ITGA9_ITGB1': 22,
#                            'COL4A3-SDC4': 36,
#                            'COL4A4-CD44': 168,
#                            'COL4A4-GP6': 18,
#                            'COL4A4-ITGA10_ITGB1': 11,
#                            'COL4A4-ITGA1_ITGB1': 26,
#                            'COL4A4-ITGA9_ITGB1': 13,
#                            'COL4A4-SDC4': 28,
#                            'COL6A1-CD44': 16,
#                            'COL6A1-GP6': 1,
#                            'COL6A1-ITGA10_ITGB1': 0,
#                            'COL6A1-ITGA1_ITGB1': 2,
#                            'COL6A1-ITGA9_ITGB1': 0,
#                            'COL6A1-SDC4': 1,
#                            'COL6A2-CD44': 32,
#                            'COL6A2-GP6': 9,
#                            'COL6A2-ITGA10_ITGB1': 4,
#                            'COL6A2-ITGA1_ITGB1': 3,
#                            'COL6A2-ITGA9_ITGB1': 4,
#                            'COL6A2-SDC4': 11,
#                            'COL6A3-CD44': 506,
#                            'COL6A3-GP6': 68,
#                            'COL6A3-ITGA10_ITGB1': 14,
#                            'COL6A3-ITGA1_ITGB1': 65,
#                            'COL6A3-ITGA9_ITGB1': 40,
#                            'COL6A3-SDC4': 65,
#                            'COL6A6-CD44': 194,
#                            'COL6A6-GP6': 30,
#                            'COL6A6-ITGA10_ITGB1': 10,
#                            'COL6A6-ITGA1_ITGB1': 29,
#                            'COL6A6-ITGA9_ITGB1': 15,
#                            'COL6A6-SDC4': 31,
#                            'COL9A2-CD44': 32,
#                            'COL9A2-GP6': 2,
#                            'COL9A2-ITGA10_ITGB1': 1,
#                            'COL9A2-ITGA1_ITGB1': 5,
#                            'COL9A2-ITGA9_ITGB1': 4,
#                            'COL9A2-SDC4': 5,
#                            'CSF1-CSF1R': 25,
#                            'CXCL10-CXCR3': 0,
#                            'CXCL12-CXCR4': 10,
#                            'CXCL13-CXCR3': 3,
#                            'CXCL13-CXCR5': 5,
#                            'CXCL16-CXCR6': 0,
#                            'CXCL9-CXCR3': 1,
#                            'DLL4-NOTCH1': 0,
#                            'EDA-EDAR': 17,
#                            'EFNA3-EPHA1': 0,
#                            'EFNA3-EPHA2': 0,
#                            'EFNA3-EPHA3': 0,
#                            'EFNA3-EPHA4': 0,
#                            'EFNA5-EPHA1': 0,
#                            'EFNA5-EPHA2': 0,
#                            'EFNA5-EPHA3': 1,
#                            'EFNA5-EPHA4': 1,
#                            'ENTPD1-TMIGD3': 3,
#                            'FCER2-CR2': 30,
#                            'FCER2-ITGAM_ITGB2': 2,
#                            'FCER2-ITGAX_ITGB2': 8,
#                            'FGF7-FGFR2': 1,
#                            'FLT3LG-FLT3': 261,
#                            'FN1-CD44': 207,
#                            'FN1-ITGA4_ITGB1': 96,
#                            'FN1-ITGA4_ITGB7': 10,
#                            'FN1-ITGA5_ITGB1': 22,
#                            'FN1-ITGA8_ITGB1': 9,
#                            'FN1-SDC4': 33,
#                            'GAS6-AXL': 33,
#                            'GAS6-MERTK': 50,
#                            'GZMA-F2R': 64,
#                            'GZMA-PARD3': 439,
#                            'HLA-G-CD8A': 1,
#                            'HLA-G-CD8B': 1,
#                            'HLA-G-LILRB2': 0,
#                            'ICAM1-ITGAM_ITGB2': 5,
#                            'ICAM1-ITGAX_ITGB2': 25,
#                            'ICAM1-SPN': 33,
#                            'ICAM2-ITGAM_ITGB2': 24,
#                            'ICOSLG-CD28': 20,
#                            'ICOSLG-CTLA4': 4,
#                            'ICOSLG-ICOS': 16,
#                            'IGF1-IGF1R': 0,
#                            'IL18-IL18R1_IL18RAP': 0,
#                            'IL34-CSF1R': 0,
#                            'IL4-IL4R': 15,
#                            'IL4-IL4R_IL13RA1': 7,
#                            'IL6-IL6R_IL6ST': 0,
#                            'ITGA4_ITGB1-VCAM1': 569,
#                            'ITGA4_ITGB7-VCAM1': 59,
#                            'ITGA9_ITGB1-VCAM1': 0,
#                            'ITGB2-CD226': 596,
#                            'ITGB2-ICAM1': 394,
#                            'ITGB2-ICAM2': 234,
#                            'JAM3-ITGAM_ITGB2': 24,
#                            'JAM3-JAM3': 96,
#                            'KITLG-KIT': 0,
#                            'LAMA3-CD44': 32,
#                            'LAMA3-ITGA1_ITGB1': 3,
#                            'LAMA3-ITGA6_ITGB1': 4,
#                            'LAMA3-ITGA9_ITGB1': 0,
#                            'LAMA3-SV2A': 0,
#                            'LAMA4-CD44': 15,
#                            'LAMA4-ITGA1_ITGB1': 3,
#                            'LAMA4-ITGA6_ITGB1': 2,
#                            'LAMA4-ITGA9_ITGB1': 1,
#                            'LAMA4-SV2A': 0,
#                            'LAMC1-CD44': 28,
#                            'LAMC1-ITGA1_ITGB1': 4,
#                            'LAMC1-ITGA6_ITGB1': 5,
#                            'LAMC1-ITGA9_ITGB1': 1,
#                            'LAMC1-SV2A': 0,
#                            'LCK-CD8A_CD8B': 53,
#                            'NCAM1-NCAM1': 5,
#                            'NCAM1-NCAM2': 5,
#                            'NECTIN1-CD96': 46,
#                            'NECTIN1-NECTIN3': 22,
#                            'NECTIN2-CD226': 0,
#                            'NECTIN2-TIGIT': 0,
#                            'NECTIN3-NECTIN1': 43,
#                            'NECTIN3-NECTIN2': 110,
#                            'NECTIN3-PVR': 43,
#                            'NECTIN3-TIGIT': 62,
#                            'NEGR1-NEGR1': 18,
#                            'NFASC-CNTN1_CNTNAP1': 0,
#                            'NPPC-NPR2': 0,
#                            'NRG1-ERBB4': 0,
#                            'NRG2-ERBB4': 0,
#                            'NRG3-ERBB4': 0,
#                            'NRXN1-NLGN1': 0,
#                            'NRXN1-NLGN3': 0,
#                            'NRXN3-NLGN1': 3,
#                            'NRXN3-NLGN3': 2,
#                            'PDCD1LG2-PDCD1': 10,
#                            'PDGFD-PDGFRB': 64,
#                            'PECAM1-PECAM1': 557,
#                            'PTPRM-PTPRM': 1237,
#                            'PVR-CD226': 29,
#                            'PVR-TIGIT': 10,
#                            'RARRES2-CMKLR1': 1,
#                            'RARRES2-GPR1': 0,
#                            'SELPLG-SELL': 312,
#                            'SELPLG-SELP': 53,
#                            'SEMA3A-NRP1_PLXNA4': 4,
#                            'SEMA3C-NRP1_NRP2_PLXND1': 0,
#                            'SEMA3C-NRP1_PLXNA4': 2,
#                            'SEMA3C-NRP2_PLXNA4': 0,
#                            'SEMA3C-PLXND1': 9,
#                            'SEMA3D-NRP1_PLXNA4': 0,
#                            'SEMA3D-NRP2_PLXNA4': 0,
#                            'SEMA6A-PLXNA4': 86,
#                            'TAC4-TACR1': 101,
#                            'THBS2-CD36': 0,
#                            'THBS2-SDC4': 0,
#                            'TIGIT-NECTIN2': 441,
#                            'TIGIT-PVR': 146,
#                            'TNC-ITGA8_ITGB1': 0,
#                            'TNC-ITGA9_ITGB1': 0,
#                            'TNC-SDC4': 0,
#                            'TNF-TNFRSF1A': 61,
#                            'TNF-TNFRSF1B': 131,
#                            'TNFSF11-TNFRSF11A': 16,
#                            'TNFSF13B-TNFRSF13B': 191,
#                            'TNFSF8-TNFRSF8': 114,
#                            'TNFSF9-TNFRSF9': 8,
#                            'TNR-ITGA8_ITGB1': 3,
#                            'TNR-ITGA9_ITGB1': 4,
#                            'TNR-SDC4': 10,
#                            'VEGFC-FLT4': 0,
#                            'VEGFC-FLT4_KDR': 0,
#                            'VEGFC-KDR': 0,
#                            'VSIR-IGSF11': 53,
#                            'WNT10A-FZD7_LRP5': 2,
#                            'WNT10A-FZD8_LRP5': 1,
#                            'WNT10B-FZD7_LRP5': 0,
#                            'WNT10B-FZD8_LRP5': 1,
#                            'WNT3-FZD7_LRP5': 1,
#                            'WNT3-FZD8_LRP5': 1,
#                            'WNT4-FZD7_LRP5': 1,
#                            'WNT4-FZD8_LRP5': 1,
#                            'WNT5B-FZD7': 15,
#                            'WNT5B-FZD8': 11,
#                            'total-total': 7590},
#                           'B memory': {'ADGRE5-CD55': 1368,
#                            'ALCAM-CD6': 196,
#                            'ANGPTL1-ITGA1_ITGB1': 1,
#                            'ANXA1-FPR1': 0,
#                            'C3-CR2': 102,
#                            'C3-ITGAM_ITGB2': 0,
#                            'C3-ITGAX_ITGB2': 11,
#                            'CADM1-CADM1': 11,
#                            'CCL19-CCR7': 23,
#                            'CCL2-CCR2': 0,
#                            'CCL20-CCR6': 158,
#                            'CCL21-CCR7': 73,
#                            'CCL3-CCR5': 1,
#                            'CCL4-CCR5': 9,
#                            'CCL5-CCR5': 25,
#                            'CD226-NECTIN2': 0,
#                            'CD226-PVR': 0,
#                            'CD274-PDCD1': 4,
#                            'CD40LG-CD40': 761,
#                            'CD40LG-ITGA5_ITGB1': 3,
#                            'CD40LG-ITGAM_ITGB2': 0,
#                            'CD6-ALCAM': 5070,
#                            'CD69-KLRB1': 145,
#                            'CD80-CD274': 3,
#                            'CD80-CD28': 4,
#                            'CD80-CTLA4': 0,
#                            'CD86-CD28': 2,
#                            'CD86-CTLA4': 0,
#                            'CD96-NECTIN1': 56,
#                            'CD96-PVR': 0,
#                            'CDH2-CDH2': 0,
#                            'CDH4-CDH4': 3,
#                            'CDH5-CDH5': 0,
#                            'CLEC2B-KLRB1': 101,
#                            'CNTN1-NRCAM': 0,
#                            'COL1A1-CD44': 0,
#                            'COL1A1-GP6': 0,
#                            'COL1A1-ITGA10_ITGB1': 0,
#                            'COL1A1-ITGA1_ITGB1': 0,
#                            'COL1A1-ITGA9_ITGB1': 0,
#                            'COL1A1-SDC4': 0,
#                            'COL1A2-CD44': 59,
#                            'COL1A2-GP6': 8,
#                            'COL1A2-ITGA10_ITGB1': 0,
#                            'COL1A2-ITGA1_ITGB1': 0,
#                            'COL1A2-ITGA9_ITGB1': 0,
#                            'COL1A2-SDC4': 0,
#                            'COL4A1-CD44': 0,
#                            'COL4A1-GP6': 0,
#                            'COL4A1-ITGA10_ITGB1': 0,
#                            'COL4A1-ITGA1_ITGB1': 0,
#                            'COL4A1-ITGA9_ITGB1': 0,
#                            'COL4A1-SDC4': 0,
#                            'COL4A3-CD44': 394,
#                            'COL4A3-GP6': 55,
# ...
#                            'IL34-CSF1R': 0,
#                            'IL4-IL4R': 2,
#                            'IL4-IL4R_IL13RA1': 0,
#                            'IL6-IL6R_IL6ST': 0,
#                            'ITGA4_ITGB1-VCAM1': 0,
#                            'ITGA4_ITGB7-VCAM1': 0,
#                            'ITGA9_ITGB1-VCAM1': 0,
#                            'ITGB2-CD226': 130,
#                            'ITGB2-ICAM1': 5,
#                            'ITGB2-ICAM2': 23,
#                            'JAM3-ITGAM_ITGB2': 0,
#                            'JAM3-JAM3': 0,
#                            'KITLG-KIT': 0,
#                            'LAMA3-CD44': 12,
#                            'LAMA3-ITGA1_ITGB1': 0,
#                            'LAMA3-ITGA6_ITGB1': 0,
#                            'LAMA3-ITGA9_ITGB1': 0,
#                            'LAMA3-SV2A': 0,
#                            'LAMA4-CD44': 11,
#                            'LAMA4-ITGA1_ITGB1': 0,
#                            'LAMA4-ITGA6_ITGB1': 0,
#                            'LAMA4-ITGA9_ITGB1': 0,
#                            'LAMA4-SV2A': 0,
#                            'LAMC1-CD44': 64,
#                            'LAMC1-ITGA1_ITGB1': 0,
#                            'LAMC1-ITGA6_ITGB1': 1,
#                            'LAMC1-ITGA9_ITGB1': 0,
#                            'LAMC1-SV2A': 1,
#                            'LCK-CD8A_CD8B': 5,
#                            'NCAM1-NCAM1': 0,
#                            'NCAM1-NCAM2': 0,
#                            'NECTIN1-CD96': 72,
#                            'NECTIN1-NECTIN3': 5,
#                            'NECTIN2-CD226': 115,
#                            'NECTIN2-TIGIT': 23,
#                            'NECTIN3-NECTIN1': 0,
#                            'NECTIN3-NECTIN2': 0,
#                            'NECTIN3-PVR': 0,
#                            'NECTIN3-TIGIT': 0,
#                            'NEGR1-NEGR1': 0,
#                            'NFASC-CNTN1_CNTNAP1': 0,
#                            'NPPC-NPR2': 0,
#                            'NRG1-ERBB4': 0,
#                            'NRG2-ERBB4': 0,
#                            'NRG3-ERBB4': 0,
#                            'NRXN1-NLGN1': 0,
#                            'NRXN1-NLGN3': 9,
#                            'NRXN3-NLGN1': 0,
#                            'NRXN3-NLGN3': 3,
#                            'PDCD1LG2-PDCD1': 15,
#                            'PDGFD-PDGFRB': 0,
#                            'PECAM1-PECAM1': 92,
#                            'PTPRM-PTPRM': 110,
#                            'PVR-CD226': 29,
#                            'PVR-TIGIT': 10,
#                            'RARRES2-CMKLR1': 0,
#                            'RARRES2-GPR1': 0,
#                            'SELPLG-SELL': 29,
#                            'SELPLG-SELP': 0,
#                            'SEMA3A-NRP1_PLXNA4': 0,
#                            'SEMA3C-NRP1_NRP2_PLXND1': 0,
#                            'SEMA3C-NRP1_PLXNA4': 0,
#                            'SEMA3C-NRP2_PLXNA4': 0,
#                            'SEMA3C-PLXND1': 0,
#                            'SEMA3D-NRP1_PLXNA4': 0,
#                            'SEMA3D-NRP2_PLXNA4': 0,
#                            'SEMA6A-PLXNA4': 5,
#                            'TAC4-TACR1': 9,
#                            'THBS2-CD36': 0,
#                            'THBS2-SDC4': 0,
#                            'TIGIT-NECTIN2': 0,
#                            'TIGIT-PVR': 0,
#                            'TNC-ITGA8_ITGB1': 0,
#                            'TNC-ITGA9_ITGB1': 0,
#                            'TNC-SDC4': 0,
#                            'TNF-TNFRSF1A': 3,
#                            'TNF-TNFRSF1B': 6,
#                            'TNFSF11-TNFRSF11A': 0,
#                            'TNFSF13B-TNFRSF13B': 12,
#                            'TNFSF8-TNFRSF8': 0,
#                            'TNFSF9-TNFRSF9': 0,
#                            'TNR-ITGA8_ITGB1': 0,
#                            'TNR-ITGA9_ITGB1': 0,
#                            'TNR-SDC4': 0,
#                            'VEGFC-FLT4': 0,
#                            'VEGFC-FLT4_KDR': 0,
#                            'VEGFC-KDR': 0,
#                            'VSIR-IGSF11': 14,
#                            'WNT10A-FZD7_LRP5': 0,
#                            'WNT10A-FZD8_LRP5': 0,
#                            'WNT10B-FZD7_LRP5': 0,
#                            'WNT10B-FZD8_LRP5': 0,
#                            'WNT3-FZD7_LRP5': 0,
#                            'WNT3-FZD8_LRP5': 0,
#                            'WNT4-FZD7_LRP5': 0,
#                            'WNT4-FZD8_LRP5': 0,
#                            'WNT5B-FZD7': 0,
#                            'WNT5B-FZD8': 0,
#                            'total-total': 1092},
#                           'Macrophages': {'ADGRE5-CD55': 29,
#                            'ALCAM-CD6': 30,
#                            'ANGPTL1-ITGA1_ITGB1': 9,
#                            'ANXA1-FPR1': 50,
#                            'C3-CR2': 7,
#                            'C3-ITGAM_ITGB2': 7,
#                            'C3-ITGAX_ITGB2': 12,
#                            'CADM1-CADM1': 122,
#                            'CCL19-CCR7': 0,
#                            'CCL2-CCR2': 0,
#                            'CCL20-CCR6': 1,
#                            'CCL21-CCR7': 2,
#                            'CCL3-CCR5': 0,
#                            'CCL4-CCR5': 0,
#                            'CCL5-CCR5': 0,
#                            'CD226-NECTIN2': 24,
#                            'CD226-PVR': 4,
#                            'CD274-PDCD1': 17,
#                            'CD40LG-CD40': 8,
#                            'CD40LG-ITGA5_ITGB1': 2,
#                            'CD40LG-ITGAM_ITGB2': 8,
#                            'CD6-ALCAM': 30,
#                            'CD69-KLRB1': 2,
#                            'CD80-CD274': 67,
#                            'CD80-CD28': 20,
#                            'CD80-CTLA4': 2,
#                            'CD86-CD28': 36,
#                            'CD86-CTLA4': 5,
#                            'CD96-NECTIN1': 5,
#                            'CD96-PVR': 8,
#                            'CDH2-CDH2': 9,
#                            'CDH4-CDH4': 1,
#                            'CDH5-CDH5': 0,
#                            'CLEC2B-KLRB1': 7,
#                            'CNTN1-NRCAM': 1,
#                            'COL1A1-CD44': 12,
#                            'COL1A1-GP6': 3,
#                            'COL1A1-ITGA10_ITGB1': 0,
#                            'COL1A1-ITGA1_ITGB1': 3,
#                            'COL1A1-ITGA9_ITGB1': 4,
#                            'COL1A1-SDC4': 3,
#                            'COL1A2-CD44': 30,
#                            'COL1A2-GP6': 7,
#                            'COL1A2-ITGA10_ITGB1': 0,
#                            'COL1A2-ITGA1_ITGB1': 5,
#                            'COL1A2-ITGA9_ITGB1': 10,
#                            'COL1A2-SDC4': 9,
#                            'COL4A1-CD44': 11,
#                            'COL4A1-GP6': 2,
#                            'COL4A1-ITGA10_ITGB1': 0,
#                            'COL4A1-ITGA1_ITGB1': 3,
#                            'COL4A1-ITGA9_ITGB1': 4,
#                            'COL4A1-SDC4': 5,
#                            'COL4A3-CD44': 47,
#                            'COL4A3-GP6': 8,
#                            'COL4A3-ITGA10_ITGB1': 2,
#                            'COL4A3-ITGA1_ITGB1': 6,
#                            'COL4A3-ITGA9_ITGB1': 17,
#                            'COL4A3-SDC4': 9,
#                            'COL4A4-CD44': 59,
#                            'COL4A4-GP6': 11,
#                            'COL4A4-ITGA10_ITGB1': 2,
#                            'COL4A4-ITGA1_ITGB1': 9,
#                            'COL4A4-ITGA9_ITGB1': 21,
#                            'COL4A4-SDC4': 15,
#                            'COL6A1-CD44': 185,
#                            'COL6A1-GP6': 27,
#                            'COL6A1-ITGA10_ITGB1': 3,
#                            'COL6A1-ITGA1_ITGB1': 16,
#                            'COL6A1-ITGA9_ITGB1': 50,
#                            'COL6A1-SDC4': 48,
#                            'COL6A2-CD44': 202,
#                            'COL6A2-GP6': 28,
#                            'COL6A2-ITGA10_ITGB1': 4,
#                            'COL6A2-ITGA1_ITGB1': 16,
#                            'COL6A2-ITGA9_ITGB1': 59,
#                            'COL6A2-SDC4': 47,
#                            'COL6A3-CD44': 11,
#                            'COL6A3-GP6': 3,
#                            'COL6A3-ITGA10_ITGB1': 0,
#                            'COL6A3-ITGA1_ITGB1': 3,
#                            'COL6A3-ITGA9_ITGB1': 5,
#                            'COL6A3-SDC4': 4,
#                            'COL6A6-CD44': 2,
#                            'COL6A6-GP6': 0,
#                            'COL6A6-ITGA10_ITGB1': 0,
#                            'COL6A6-ITGA1_ITGB1': 0,
#                            'COL6A6-ITGA9_ITGB1': 2,
#                            'COL6A6-SDC4': 1,
#                            'COL9A2-CD44': 15,
#                            'COL9A2-GP6': 4,
#                            'COL9A2-ITGA10_ITGB1': 0,
#                            'COL9A2-ITGA1_ITGB1': 2,
#                            'COL9A2-ITGA9_ITGB1': 4,
#                            'COL9A2-SDC4': 4,
#                            'CSF1-CSF1R': 25,
#                            'CXCL10-CXCR3': 0,
#                            'CXCL12-CXCR4': 22,
#                            'CXCL13-CXCR3': 0,
#                            'CXCL13-CXCR5': 21,
#                            'CXCL16-CXCR6': 1,
#                            'CXCL9-CXCR3': 0,
#                            'DLL4-NOTCH1': 2,
#                            'EDA-EDAR': 0,
#                            'EFNA3-EPHA1': 0,
#                            'EFNA3-EPHA2': 0,
#                            'EFNA3-EPHA3': 0,
#                            'EFNA3-EPHA4': 0,
#                            'EFNA5-EPHA1': 0,
#                            'EFNA5-EPHA2': 1,
#                            'EFNA5-EPHA3': 1,
#                            'EFNA5-EPHA4': 1,
#                            'ENTPD1-TMIGD3': 6,
#                            'FCER2-CR2': 17,
#                            'FCER2-ITGAM_ITGB2': 21,
#                            'FCER2-ITGAX_ITGB2': 26,
#                            'FGF7-FGFR2': 1,
#                            'FLT3LG-FLT3': 0,
#                            'FN1-CD44': 60,
#                            'FN1-ITGA4_ITGB1': 23,
#                            'FN1-ITGA4_ITGB7': 5,
#                            'FN1-ITGA5_ITGB1': 6,
#                            'FN1-ITGA8_ITGB1': 0,
#                            'FN1-SDC4': 18,
#                            'GAS6-AXL': 15,
#                            'GAS6-MERTK': 100,
#                            'GZMA-F2R': 0,
#                            'GZMA-PARD3': 0,
#                            'HLA-G-CD8A': 0,
#                            'HLA-G-CD8B': 0,
#                            'HLA-G-LILRB2': 0,
#                            'ICAM1-ITGAM_ITGB2': 47,
#                            'ICAM1-ITGAX_ITGB2': 75,
#                            'ICAM1-SPN': 29,
#                            'ICAM2-ITGAM_ITGB2': 10,
#                            'ICOSLG-CD28': 5,
#                            'ICOSLG-CTLA4': 1,
#                            'ICOSLG-ICOS': 4,
#                            'IGF1-IGF1R': 155,
#                            'IL18-IL18R1_IL18RAP': 0,
#                            'IL34-CSF1R': 6,
#                            'IL4-IL4R': 10,
#                            'IL4-IL4R_IL13RA1': 10,
#                            'IL6-IL6R_IL6ST': 0,
#                            'ITGA4_ITGB1-VCAM1': 53,
#                            'ITGA4_ITGB7-VCAM1': 7,
#                            'ITGA9_ITGB1-VCAM1': 42,
#                            'ITGB2-CD226': 44,
#                            'ITGB2-ICAM1': 76,
#                            'ITGB2-ICAM2': 15,
#                            'JAM3-ITGAM_ITGB2': 15,
#                            'JAM3-JAM3': 9,
#                            'KITLG-KIT': 0,
#                            'LAMA3-CD44': 11,
#                            'LAMA3-ITGA1_ITGB1': 2,
#                            'LAMA3-ITGA6_ITGB1': 5,
#                            'LAMA3-ITGA9_ITGB1': 3,
#                            'LAMA3-SV2A': 0,
#                            'LAMA4-CD44': 9,
#                            'LAMA4-ITGA1_ITGB1': 3,
#                            'LAMA4-ITGA6_ITGB1': 4,
#                            'LAMA4-ITGA9_ITGB1': 4,
#                            'LAMA4-SV2A': 0,
#                            'LAMC1-CD44': 55,
#                            'LAMC1-ITGA1_ITGB1': 8,
#                            'LAMC1-ITGA6_ITGB1': 17,
#                            'LAMC1-ITGA9_ITGB1': 19,
#                            'LAMC1-SV2A': 1,
#                            'LCK-CD8A_CD8B': 0,
#                            'NCAM1-NCAM1': 1,
#                            'NCAM1-NCAM2': 3,
#                            'NECTIN1-CD96': 5,
#                            'NECTIN1-NECTIN3': 0,
#                            'NECTIN2-CD226': 24,
#                            'NECTIN2-TIGIT': 6,
#                            'NECTIN3-NECTIN1': 0,
#                            'NECTIN3-NECTIN2': 3,
#                            'NECTIN3-PVR': 1,
#                            'NECTIN3-TIGIT': 0,
#                            'NEGR1-NEGR1': 3,
#                            'NFASC-CNTN1_CNTNAP1': 0,
#                            'NPPC-NPR2': 1,
#                            'NRG1-ERBB4': 0,
#                            'NRG2-ERBB4': 1,
#                            'NRG3-ERBB4': 1,
#                            'NRXN1-NLGN1': 0,
#                            'NRXN1-NLGN3': 21,
#                            'NRXN3-NLGN1': 0,
#                            'NRXN3-NLGN3': 5,
#                            'PDCD1LG2-PDCD1': 30,
#                            'PDGFD-PDGFRB': 7,
#                            'PECAM1-PECAM1': 89,
#                            'PTPRM-PTPRM': 260,
#                            'PVR-CD226': 4,
#                            'PVR-TIGIT': 2,
#                            'RARRES2-CMKLR1': 150,
#                            'RARRES2-GPR1': 0,
#                            'SELPLG-SELL': 18,
#                            'SELPLG-SELP': 0,
#                            'SEMA3A-NRP1_PLXNA4': 0,
#                            'SEMA3C-NRP1_NRP2_PLXND1': 3,
#                            'SEMA3C-NRP1_PLXNA4': 0,
#                            'SEMA3C-NRP2_PLXNA4': 0,
#                            'SEMA3C-PLXND1': 5,
#                            'SEMA3D-NRP1_PLXNA4': 0,
#                            'SEMA3D-NRP2_PLXNA4': 1,
#                            'SEMA6A-PLXNA4': 0,
#                            'TAC4-TACR1': 3,
#                            'THBS2-CD36': 1,
#                            'THBS2-SDC4': 2,
#                            'TIGIT-NECTIN2': 6,
#                            'TIGIT-PVR': 2,
#                            'TNC-ITGA8_ITGB1': 0,
#                            'TNC-ITGA9_ITGB1': 2,
#                            'TNC-SDC4': 1,
#                            'TNF-TNFRSF1A': 7,
#                            'TNF-TNFRSF1B': 11,
#                            'TNFSF11-TNFRSF11A': 0,
#                            'TNFSF13B-TNFRSF13B': 6,
#                            'TNFSF8-TNFRSF8': 2,
#                            'TNFSF9-TNFRSF9': 0,
#                            'TNR-ITGA8_ITGB1': 1,
#                            'TNR-ITGA9_ITGB1': 7,
#                            'TNR-SDC4': 1,
#                            'VEGFC-FLT4': 1,
#                            'VEGFC-FLT4_KDR': 1,
#                            'VEGFC-KDR': 2,
#                            'VSIR-IGSF11': 8,
#                            'WNT10A-FZD7_LRP5': 0,
#                            'WNT10A-FZD8_LRP5': 0,
#                            'WNT10B-FZD7_LRP5': 0,
#                            'WNT10B-FZD8_LRP5': 0,
#                            'WNT3-FZD7_LRP5': 0,
#                            'WNT3-FZD8_LRP5': 0,
#                            'WNT4-FZD7_LRP5': 0,
#                            'WNT4-FZD8_LRP5': 0,
#                            'WNT5B-FZD7': 0,
#                            'WNT5B-FZD8': 0,
#                            'total-total': 444}})})
