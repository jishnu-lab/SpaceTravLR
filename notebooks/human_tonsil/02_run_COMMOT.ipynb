# %%
import commot as ct
import scanpy as sc
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ### Run Commot

# %%
adata = sc.read_h5ad('/Users/koush/Desktop/training_data/snrna_human_tonsil.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 5778 × 3333
#     obs: 'cell_type', 'author_cell_type', 'cell_type_int', 'banksy_celltypes'
#     obsm: 'spatial', 'spatial_unscaled'
#     layers: 'imputed_count', 'normalized_count'

# %%
# adata.X = adata.layers['imputed_count']
adata.X = adata.layers['normalized_count']

# %%
adata.X.max()
# Out:
# 8.8678228953803

# %%
df_ligrec = ct.pp.ligand_receptor_database(
    database='CellChat', 
    species='human', 
    signaling_type=None
)

df_ligrec.columns = ['ligand', 'receptor', 'pathway', 'signaling']  
df_ligrec['name'] = df_ligrec['ligand'] + '-' + df_ligrec['receptor']
len(df_ligrec['name'].unique())
# Out:
# 1938

# %%
import sys
sys.path.append('../../src')
from spaceoracle.tools.network import expand_paired_interactions

expanded = expand_paired_interactions(df_ligrec)
genes = set(expanded.ligand) | set(expanded.receptor)
genes = list(genes)

expanded
# Out:
#      ligand receptor pathway           signaling                 name
# 0     TGFB1   TGFBR1    TGFb  Secreted Signaling  TGFB1-TGFBR1_TGFBR2
# 0     TGFB1   TGFBR2    TGFb  Secreted Signaling  TGFB1-TGFBR1_TGFBR2
# 1     TGFB2   TGFBR1    TGFb  Secreted Signaling  TGFB2-TGFBR1_TGFBR2
# 1     TGFB2   TGFBR2    TGFb  Secreted Signaling  TGFB2-TGFBR1_TGFBR2
# 2     TGFB3   TGFBR1    TGFb  Secreted Signaling  TGFB3-TGFBR1_TGFBR2
# ...     ...      ...     ...                 ...                  ...
# 1936  ITGA9    VCAM1    VCAM   Cell-Cell Contact    ITGA9_ITGB1-VCAM1
# 1936  ITGB1    VCAM1    VCAM   Cell-Cell Contact    ITGA9_ITGB1-VCAM1
# 1937  ITGA4    VCAM1    VCAM   Cell-Cell Contact    ITGA4_ITGB7-VCAM1
# 1937  ITGB7    VCAM1    VCAM   Cell-Cell Contact    ITGA4_ITGB7-VCAM1
# 1938   VSIR   IGSF11   VISTA   Cell-Cell Contact          VSIR-IGSF11
#
# [2914 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [3, 3]
sc.pl.embedding(adata, 'spatial', color='cell_type_int')

# %%
expanded = expanded[expanded.ligand.isin(adata.var_names) & expanded.receptor.isin(adata.var_names)]

# %%
# %%time

ct.tl.spatial_communication(adata,
    database_name='user_database', 
    # df_ligrec=df_ligrec, 
    df_ligrec=expanded, 
    dis_thr=350, 
    # heteromeric=True
    heteromeric=False
)
# Out:
# CPU times: user 54min 34s, sys: 10min 26s, total: 1h 5min 1s
# Wall time: 1h 5min 12s

# %%
adata.write_h5ad('/Users/koush/Desktop/training_data/snrna_human_tonsil.h5ad')

# %%
expanded['rename'] = expanded['ligand'] + '-' + expanded['receptor']

# %%
from tqdm import tqdm
import commot as ct

for name in tqdm(expanded['rename'].unique()):

    ct.tl.cluster_communication(
        adata, 
        database_name='user_database', 
        pathway_name=name, 
        clustering='cell_type',
        random_seed=12, 
        n_permutations=100
    )
# Out:
# 100%|██████████| 958/958 [40:11<00:00,  2.52s/it]

# %%
adata.write_h5ad('/Users/koush/Desktop/training_data/snrna_human_tonsil.h5ad')

# %%
from collections import defaultdict
data_dict = defaultdict(dict)

for name in expanded['rename']:
    data_dict[name]['communication_matrix'] = adata.uns[
        f'commot_cluster-cell_type-user_database-{name}']['communication_matrix']
    data_dict[name]['communication_pvalue'] = adata.uns[
        f'commot_cluster-cell_type-user_database-{name}']['communication_pvalue']

import pickle
with open('/Users/koush/Desktop/training_data/tonsil_communication.pkl', 'wb') as f:
    pickle.dump(data_dict, f)

# %%
# check outputs

import pickle
with open('/Users/koush/Desktop/training_data/tonsil_communication.pkl', 'rb') as f:
    info = pickle.load(f)

len(info.keys())
# Out:
# 958

# %%
def get_sig_interactions(value_matrix, p_matrix, pval=0.3):
    p_matrix = np.where(p_matrix < pval, 1, 0)
    return value_matrix * p_matrix

interactions = {}
for lig, rec in tqdm(zip(expanded['ligand'], expanded['receptor'])):
    name = lig + '-' + rec

    if name in info.keys():

        value_matrix = info[name]['communication_matrix']
        p_matrix = info[name]['communication_pvalue']

        sig_matrix = get_sig_interactions(value_matrix, p_matrix)
        
        if sig_matrix.sum().sum() > 0:
            interactions[name] = sig_matrix
    
len(interactions)
# Out:
# 1397it [00:00, 6263.53it/s]
# 958

# %% [markdown]
# ### Get expanded LR masks

# %%
len(interactions.keys())
# Out:
# 958

# %%
# create cell x gene matrix
ct_masks = {ct: adata.obs['cell_type'] == ct for ct in adata.obs['cell_type'].unique()}

df = pd.DataFrame(index=adata.obs_names, columns=genes)
df = df.fillna(0)

for name in tqdm(interactions.keys(), total=len(interactions)):
    lig, rec = name.rsplit('-', 1)
    
    tmp = interactions[name].sum(axis=1)
    for ct, val in zip(interactions[name].index, tmp):
        df.loc[ct_masks[ct], lig] += tmp[ct]
    
    tmp = interactions[name].sum(axis=0)
    for ct, val in zip(interactions[name].columns, tmp):
        df.loc[ct_masks[ct], rec] += tmp[ct]

df.shape
# Out:
# 100%|██████████| 958/958 [00:18<00:00, 52.70it/s]
# (5778, 958)

# %%
print('Number of LR filtered using celltype specificity:')
np.where(df > 0, 1, 0).sum().sum() / (df.shape[0] * df.shape[1])
# Out:
# Number of LR filtered using celltype specificity:
# 0.3755467611290685

# %%
df.to_parquet('/Users/koush/Desktop/training_data/tonsil_LRs.parquet')

# %%
ligands = ['IL2', 'IL7']
df[ligands].sum(axis=0)
# Out:
# IL2    0.000000
# IL7    5.405941
# dtype: float64

# %% [markdown]
# ### Get ligand receivers mask for tissue density weighting

# %%
df = pd.read_parquet('/Users/koush/Desktop/training_data/tonsil_LRs.parquet')
df.head(3)
# Out:
#                     ADORA1   HLA-DOA  CCL2      TAC4  CCL1  CHRNE  WNT8B  \
# NAME
# AAACCCAAGCGCCTTG-1       0  0.000000   0.0  0.000201     0      0      0
# AAACCCAAGTGGACGT-1       0  0.000133   0.0  0.000074     0      0      0
# AAACCCACAGAAGTGC-1       0  0.000513   0.0  0.000000     0      0      0
#
#                      ADORA2B  IL13RA2      CD27  ...  TSHR       PGF  \
# NAME                                             ...
# AAACCCAAGCGCCTTG-1  0.000000        0  0.000036  ...     0  0.000000
# AAACCCAAGTGGACGT-1  0.000000        0  0.000146  ...     0  0.000000
# AAACCCACAGAAGTGC-1  0.000002        0  0.000048  ...     0  0.000003
#
#                          CD6  MCHR1     CNTN2  NTSR1      GAS6  CHRNG  IL25  \
# NAME
# AAACCCAAGCGCCTTG-1  0.005608      0  0.000007      0  0.000267      0     0
# AAACCCAAGTGGACGT-1  0.000000      0  0.000006      0  0.002320      0     0
# AAACCCACAGAAGTGC-1  0.000000      0  0.000005      0  0.000204      0     0
#
#                     UCN3
# NAME
# AAACCCAAGCGCCTTG-1     0
# AAACCCAAGTGGACGT-1     0
# AAACCCACAGAAGTGC-1     0
#
# [3 rows x 958 columns]

# %%
ligand_receivers_mask = pd.DataFrame(
    index=df.index, 
    columns=np.unique(expanded.ligand)
).fillna(0)

for _, row in tqdm(expanded.iterrows(), total=len(expanded)):
    ligand = row.ligand
    receptor = row.receptor

    receivers = df[receptor].values
    ligand_receivers_mask.loc[:, ligand] += receivers

ligand_receivers_mask.head(3)
# Out:
# 100%|██████████| 1397/1397 [00:00<00:00, 3778.87it/s]
#                       ADGRE5      AGRN     ALCAM    ANGPT1    ANGPT2  \
# NAME
# AAACCCAAGCGCCTTG-1  0.000649  0.000328  0.005608  0.000000  0.002069
# AAACCCAAGTGGACGT-1  0.000275  0.000607  0.000000  0.000015  0.001769
# AAACCCACAGAAGTGC-1  0.000111  0.000399  0.000000  0.000001  0.002865
#
#                      ANGPTL1   ANGPTL2   ANGPTL3   ANGPTL4   ANGPTL7  ...  \
# NAME                                                                  ...
# AAACCCAAGCGCCTTG-1  0.002611  0.002077  0.000581  0.002650  0.000008  ...
# AAACCCAAGTGGACGT-1  0.001790  0.001778  0.001234  0.007357  0.000025  ...
# AAACCCACAGAAGTGC-1  0.002919  0.002883  0.000901  0.003848  0.000019  ...
#
#                       WNT10A    WNT10B     WNT16     WNT2B      WNT3  \
# NAME
# AAACCCAAGCGCCTTG-1  0.002734  0.002734  0.002734  0.002734  0.002734
# AAACCCAAGTGGACGT-1  0.008917  0.008917  0.008917  0.008917  0.008917
# AAACCCACAGAAGTGC-1  0.002493  0.002493  0.002493  0.002493  0.002493
#
#                         WNT4     WNT5A     WNT5B      WNT6     WNT7A
# NAME
# AAACCCAAGCGCCTTG-1  0.002734  0.000417  0.000417  0.002734  0.002734
# AAACCCAAGTGGACGT-1  0.008917  0.002929  0.002920  0.008917  0.008917
# AAACCCACAGAAGTGC-1  0.002493  0.000654  0.000635  0.002493  0.002493
#
# [3 rows x 277 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5778 × 3333
#     obs: 'cell_type', 'author_cell_type', 'cell_type_int', 'banksy_celltypes'
#     uns: 'cell_type_int_colors', 'commot-user_database-info', 'commot_cluster-cell_type-user_database-TGFB1-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB1-TGFBR2', 'commot_cluster-cell_type-user_database-TGFB2-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB2-TGFBR2', 'commot_cluster-cell_type-user_database-TGFB3-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB3-TGFBR2', 'commot_cluster-cell_type-user_database-BMP2-BMPR1A', 'commot_cluster-cell_type-user_database-BMP2-BMPR2', 'commot_cluster-cell_type-user_database-BMP2-BMPR1B', 'commot_cluster-cell_type-user_database-GDF7-BMPR1A', 'commot_cluster-cell_type-user_database-GDF7-BMPR2', 'commot_cluster-cell_type-user_database-GDF7-BMPR1B', 'commot_cluster-cell_type-user_database-BMP6-BMPR2', 'commot_cluster-cell_type-user_database-BMP6-BMPR1A', 'commot_cluster-cell_type-user_database-BMP6-BMPR1B', 'commot_cluster-cell_type-user_database-BMP7-BMPR2', 'commot_cluster-cell_type-user_database-BMP7-BMPR1A', 'commot_cluster-cell_type-user_database-BMP7-BMPR1B', 'commot_cluster-cell_type-user_database-BMP8A-BMPR2', 'commot_cluster-cell_type-user_database-BMP8A-BMPR1A', 'commot_cluster-cell_type-user_database-BMP8A-BMPR1B', 'commot_cluster-cell_type-user_database-BMP8B-BMPR2', 'commot_cluster-cell_type-user_database-BMP8B-BMPR1A', 'commot_cluster-cell_type-user_database-BMP8B-BMPR1B', 'commot_cluster-cell_type-user_database-GDF11-TGFBR1', 'commot_cluster-cell_type-user_database-WNT10A-LRP5', 'commot_cluster-cell_type-user_database-WNT10A-FZD2', 'commot_cluster-cell_type-user_database-WNT10A-FZD3', 'commot_cluster-cell_type-user_database-WNT10A-FZD6', 'commot_cluster-cell_type-user_database-WNT10A-FZD7', 'commot_cluster-cell_type-user_database-WNT10A-FZD8', 'commot_cluster-cell_type-user_database-WNT10B-LRP5', 'commot_cluster-cell_type-user_database-WNT10B-FZD2', 'commot_cluster-cell_type-user_database-WNT10B-FZD3', 'commot_cluster-cell_type-user_database-WNT10B-FZD6', 'commot_cluster-cell_type-user_database-WNT10B-FZD7', 'commot_cluster-cell_type-user_database-WNT10B-FZD8', 'commot_cluster-cell_type-user_database-WNT16-LRP5', 'commot_cluster-cell_type-user_database-WNT16-FZD2', 'commot_cluster-cell_type-user_database-WNT16-FZD3', 'commot_cluster-cell_type-user_database-WNT16-FZD6', 'commot_cluster-cell_type-user_database-WNT16-FZD7', 'commot_cluster-cell_type-user_database-WNT16-FZD8', 'commot_cluster-cell_type-user_database-WNT2B-LRP5', 'commot_cluster-cell_type-user_database-WNT2B-FZD2', 'commot_cluster-cell_type-user_database-WNT2B-FZD3', 'commot_cluster-cell_type-user_database-WNT2B-FZD6', 'commot_cluster-cell_type-user_database-WNT2B-FZD7', 'commot_cluster-cell_type-user_database-WNT2B-FZD8', 'commot_cluster-cell_type-user_database-WNT3-LRP5', 'commot_cluster-cell_type-user_database-WNT3-FZD2', 'commot_cluster-cell_type-user_database-WNT3-FZD3', 'commot_cluster-cell_type-user_database-WNT3-FZD6', 'commot_cluster-cell_type-user_database-WNT3-FZD7', 'commot_cluster-cell_type-user_database-WNT3-FZD8', 'commot_cluster-cell_type-user_database-WNT4-LRP5', 'commot_cluster-cell_type-user_database-WNT4-FZD2', 'commot_cluster-cell_type-user_database-WNT4-FZD3', 'commot_cluster-cell_type-user_database-WNT4-FZD6', 'commot_cluster-cell_type-user_database-WNT4-FZD7', 'commot_cluster-cell_type-user_database-WNT4-FZD8', 'commot_cluster-cell_type-user_database-WNT6-LRP5', 'commot_cluster-cell_type-user_database-WNT6-FZD2', 'commot_cluster-cell_type-user_database-WNT6-FZD3', 'commot_cluster-cell_type-user_database-WNT6-FZD6', 'commot_cluster-cell_type-user_database-WNT6-FZD7', 'commot_cluster-cell_type-user_database-WNT6-FZD8', 'commot_cluster-cell_type-user_database-WNT7A-LRP5', 'commot_cluster-cell_type-user_database-WNT7A-FZD2', 'commot_cluster-cell_type-user_database-WNT7A-FZD3', 'commot_cluster-cell_type-user_database-WNT7A-FZD6', 'commot_cluster-cell_type-user_database-WNT7A-FZD7', 'commot_cluster-cell_type-user_database-WNT7A-FZD8', 'commot_cluster-cell_type-user_database-WNT ...
#     obsm: 'spatial', 'spatial_unscaled', 'commot-user_database-sum-sender', 'commot-user_database-sum-receiver'
#     layers: 'imputed_count', 'normalized_count'
#     obsp: 'commot-user_database-HLA-DOA-CD4', 'commot-user_database-CCL2-CCR2', 'commot-user_database-TAC4-TACR1', 'commot-user_database-VSIR-IGSF11', 'commot-user_database-DLL4-NOTCH1', 'commot-user_database-DLL4-NOTCH4', 'commot-user_database-DLL4-NOTCH2', 'commot-user_database-DLL4-NOTCH3', 'commot-user_database-HLA-DRA-CD4', 'commot-user_database-HLA-B-CD8A', 'commot-user_database-HLA-B-CD8B', 'commot-user_database-HLA-B-CD8B2', 'commot-user_database-PRSS3-PARD3', 'commot-user_database-PRSS3-F2R', 'commot-user_database-PRSS3-F2RL3', 'commot-user_database-PRSS3-F2RL2', 'commot-user_database-IL6-IL6R', 'commot-user_database-IL6-IL6ST', 'commot-user_database-PRSS2-PARD3', 'commot-user_database-PRSS2-F2R', 'commot-user_database-PRSS2-F2RL3', 'commot-user_database-PRSS2-F2RL2', 'commot-user_database-TNFSF15-TNFRSF25', 'commot-user_database-ALCAM-CD6', 'commot-user_database-BTLA-TNFRSF14', 'commot-user_database-IGF1-ITGB4', 'commot-user_database-IGF1-IGF1R', 'commot-user_database-IGF1-ITGAV', 'commot-user_database-IGF1-ITGA6', 'commot-user_database-PTPRM-PTPRM', 'commot-user_database-CD70-CD27', 'commot-user_database-COL6A6-ITGA10', 'commot-user_database-COL6A6-SDC4', 'commot-user_database-COL6A6-ITGA11', 'commot-user_database-COL6A6-ITGB1', 'commot-user_database-COL6A6-ITGB8', 'commot-user_database-COL6A6-ITGA2', 'commot-user_database-COL6A6-ITGA3', 'commot-user_database-COL6A6-ITGA1', 'commot-user_database-COL6A6-SDC1', 'commot-user_database-COL6A6-GP6', 'commot-user_database-COL6A6-ITGAV', 'commot-user_database-COL6A6-CD44', 'commot-user_database-COL6A6-ITGA9', 'commot-user_database-CD274-PDCD1', 'commot-user_database-THBS3-CD47', 'commot-user_database-THBS3-SDC4', 'commot-user_database-THBS3-ITGB1', 'commot-user_database-THBS3-ITGA3', 'commot-user_database-THBS3-SDC1', 'commot-user_database-THBS3-CD36', 'commot-user_database-THBS3-ITGAV', 'commot-user_database-HLA-DRB5-CD4', 'commot-user_database-CD40LG-ITGB2', 'commot-user_database-CD40LG-ITGB1', 'commot-user_database-CD40LG-CD40', 'commot-user_database-CD40LG-ITGA5', 'commot-user_database-CD40LG-ITGAM', 'commot-user_database-TIGIT-NECTIN2', 'commot-user_database-TIGIT-PVR', 'commot-user_database-CLCF1-IL6ST', 'commot-user_database-CLCF1-LIFR', 'commot-user_database-EFNA5-EPHB2', 'commot-user_database-EFNA5-EPHA3', 'commot-user_database-EFNA5-EPHA1', 'commot-user_database-EFNA5-EPHA2', 'commot-user_database-EFNA5-EPHA4', 'commot-user_database-NFASC-CNTNAP1', 'commot-user_database-NFASC-CNTN1', 'commot-user_database-IL15-IL2RG', 'commot-user_database-IL15-IL2RB', 'commot-user_database-IL15-IL15RA', 'commot-user_database-PDGFA-PDGFRA', 'commot-user_database-PDGFA-PDGFRB', 'commot-user_database-LAMA3-ITGA7', 'commot-user_database-LAMA3-ITGB1', 'commot-user_database-LAMA3-SV2C', 'commot-user_database-LAMA3-DAG1', 'commot-user_database-LAMA3-ITGB8', 'commot-user_database-LAMA3-ITGA2', 'commot-user_database-LAMA3-ITGA3', 'commot-user_database-LAMA3-ITGA1', 'commot-user_database-LAMA3-SV2B', 'commot-user_database-LAMA3-ITGB4', 'commot-user_database-LAMA3-ITGAV', 'commot-user_database-LAMA3-CD44', 'commot-user_database-LAMA3-ITGA9', 'commot-user_database-LAMA3-ITGA6', 'commot-user_database-CDH5-CDH5', 'commot-user_database-NAMPT-ITGB1', 'commot-user_database-NAMPT-ITGA5', 'commot-user_database-NAMPT-INSR', 'commot-user_database-CCL17-CCR4', 'commot-user_database-WNT4-FZD7', 'commot-user_database-WNT4-LRP6', 'commot-user_database-WNT4-FZD2', 'commot-user_database-WNT4-FZD8', 'commot-user_database-WNT4-FZD6', 'commot-user_database-WNT4-LRP5', 'commot-user_database-WNT4-FZD3', 'commot-user_database-RELN-ITGB1', 'commot-user_database-RELN-ITGA3', 'commot-user_database-WNT10A-FZD7', 'commot-user_database-WNT10A-LRP6', 'commot-user_database-WNT10A-FZD2', 'commot-user_database-WNT10A-FZD8', 'commot-user_database-WNT10A-FZD6', 'commot-user_database-WNT10A-LRP5', 'commot-user_database-WNT10A-FZD3', 'commot-user_database-FREM1-ITGB1', 'commot-user_database-FREM1-ITGA8', 'commot-user_database ...

# %%
from spaceoracle.models.parallel_estimators import *

cell_threshes = pd.read_parquet(
    '/Users/koush/Desktop/training_data/tonsil_LRs.parquet')
adata.uns['cell_thresholds'] = cell_threshes
adata
# Out:
# AnnData object with n_obs × n_vars = 5778 × 3333
#     obs: 'cell_type', 'author_cell_type', 'cell_type_int', 'banksy_celltypes'
#     uns: 'cell_type_int_colors', 'commot-user_database-info', 'commot_cluster-cell_type-user_database-TGFB1-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB1-TGFBR2', 'commot_cluster-cell_type-user_database-TGFB2-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB2-TGFBR2', 'commot_cluster-cell_type-user_database-TGFB3-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB3-TGFBR2', 'commot_cluster-cell_type-user_database-BMP2-BMPR1A', 'commot_cluster-cell_type-user_database-BMP2-BMPR2', 'commot_cluster-cell_type-user_database-BMP2-BMPR1B', 'commot_cluster-cell_type-user_database-GDF7-BMPR1A', 'commot_cluster-cell_type-user_database-GDF7-BMPR2', 'commot_cluster-cell_type-user_database-GDF7-BMPR1B', 'commot_cluster-cell_type-user_database-BMP6-BMPR2', 'commot_cluster-cell_type-user_database-BMP6-BMPR1A', 'commot_cluster-cell_type-user_database-BMP6-BMPR1B', 'commot_cluster-cell_type-user_database-BMP7-BMPR2', 'commot_cluster-cell_type-user_database-BMP7-BMPR1A', 'commot_cluster-cell_type-user_database-BMP7-BMPR1B', 'commot_cluster-cell_type-user_database-BMP8A-BMPR2', 'commot_cluster-cell_type-user_database-BMP8A-BMPR1A', 'commot_cluster-cell_type-user_database-BMP8A-BMPR1B', 'commot_cluster-cell_type-user_database-BMP8B-BMPR2', 'commot_cluster-cell_type-user_database-BMP8B-BMPR1A', 'commot_cluster-cell_type-user_database-BMP8B-BMPR1B', 'commot_cluster-cell_type-user_database-GDF11-TGFBR1', 'commot_cluster-cell_type-user_database-WNT10A-LRP5', 'commot_cluster-cell_type-user_database-WNT10A-FZD2', 'commot_cluster-cell_type-user_database-WNT10A-FZD3', 'commot_cluster-cell_type-user_database-WNT10A-FZD6', 'commot_cluster-cell_type-user_database-WNT10A-FZD7', 'commot_cluster-cell_type-user_database-WNT10A-FZD8', 'commot_cluster-cell_type-user_database-WNT10B-LRP5', 'commot_cluster-cell_type-user_database-WNT10B-FZD2', 'commot_cluster-cell_type-user_database-WNT10B-FZD3', 'commot_cluster-cell_type-user_database-WNT10B-FZD6', 'commot_cluster-cell_type-user_database-WNT10B-FZD7', 'commot_cluster-cell_type-user_database-WNT10B-FZD8', 'commot_cluster-cell_type-user_database-WNT16-LRP5', 'commot_cluster-cell_type-user_database-WNT16-FZD2', 'commot_cluster-cell_type-user_database-WNT16-FZD3', 'commot_cluster-cell_type-user_database-WNT16-FZD6', 'commot_cluster-cell_type-user_database-WNT16-FZD7', 'commot_cluster-cell_type-user_database-WNT16-FZD8', 'commot_cluster-cell_type-user_database-WNT2B-LRP5', 'commot_cluster-cell_type-user_database-WNT2B-FZD2', 'commot_cluster-cell_type-user_database-WNT2B-FZD3', 'commot_cluster-cell_type-user_database-WNT2B-FZD6', 'commot_cluster-cell_type-user_database-WNT2B-FZD7', 'commot_cluster-cell_type-user_database-WNT2B-FZD8', 'commot_cluster-cell_type-user_database-WNT3-LRP5', 'commot_cluster-cell_type-user_database-WNT3-FZD2', 'commot_cluster-cell_type-user_database-WNT3-FZD3', 'commot_cluster-cell_type-user_database-WNT3-FZD6', 'commot_cluster-cell_type-user_database-WNT3-FZD7', 'commot_cluster-cell_type-user_database-WNT3-FZD8', 'commot_cluster-cell_type-user_database-WNT4-LRP5', 'commot_cluster-cell_type-user_database-WNT4-FZD2', 'commot_cluster-cell_type-user_database-WNT4-FZD3', 'commot_cluster-cell_type-user_database-WNT4-FZD6', 'commot_cluster-cell_type-user_database-WNT4-FZD7', 'commot_cluster-cell_type-user_database-WNT4-FZD8', 'commot_cluster-cell_type-user_database-WNT6-LRP5', 'commot_cluster-cell_type-user_database-WNT6-FZD2', 'commot_cluster-cell_type-user_database-WNT6-FZD3', 'commot_cluster-cell_type-user_database-WNT6-FZD6', 'commot_cluster-cell_type-user_database-WNT6-FZD7', 'commot_cluster-cell_type-user_database-WNT6-FZD8', 'commot_cluster-cell_type-user_database-WNT7A-LRP5', 'commot_cluster-cell_type-user_database-WNT7A-FZD2', 'commot_cluster-cell_type-user_database-WNT7A-FZD3', 'commot_cluster-cell_type-user_database-WNT7A-FZD6', 'commot_cluster-cell_type-user_database-WNT7A-FZD7', 'commot_cluster-cell_type-user_database-WNT7A-FZD8', 'commot_cluster-cell_type-user_database-WNT ...
#     obsm: 'spatial', 'spatial_unscaled', 'commot-user_database-sum-sender', 'commot-user_database-sum-receiver'
#     layers: 'imputed_count', 'normalized_count'
#     obsp: 'commot-user_database-HLA-DOA-CD4', 'commot-user_database-CCL2-CCR2', 'commot-user_database-TAC4-TACR1', 'commot-user_database-VSIR-IGSF11', 'commot-user_database-DLL4-NOTCH1', 'commot-user_database-DLL4-NOTCH4', 'commot-user_database-DLL4-NOTCH2', 'commot-user_database-DLL4-NOTCH3', 'commot-user_database-HLA-DRA-CD4', 'commot-user_database-HLA-B-CD8A', 'commot-user_database-HLA-B-CD8B', 'commot-user_database-HLA-B-CD8B2', 'commot-user_database-PRSS3-PARD3', 'commot-user_database-PRSS3-F2R', 'commot-user_database-PRSS3-F2RL3', 'commot-user_database-PRSS3-F2RL2', 'commot-user_database-IL6-IL6R', 'commot-user_database-IL6-IL6ST', 'commot-user_database-PRSS2-PARD3', 'commot-user_database-PRSS2-F2R', 'commot-user_database-PRSS2-F2RL3', 'commot-user_database-PRSS2-F2RL2', 'commot-user_database-TNFSF15-TNFRSF25', 'commot-user_database-ALCAM-CD6', 'commot-user_database-BTLA-TNFRSF14', 'commot-user_database-IGF1-ITGB4', 'commot-user_database-IGF1-IGF1R', 'commot-user_database-IGF1-ITGAV', 'commot-user_database-IGF1-ITGA6', 'commot-user_database-PTPRM-PTPRM', 'commot-user_database-CD70-CD27', 'commot-user_database-COL6A6-ITGA10', 'commot-user_database-COL6A6-SDC4', 'commot-user_database-COL6A6-ITGA11', 'commot-user_database-COL6A6-ITGB1', 'commot-user_database-COL6A6-ITGB8', 'commot-user_database-COL6A6-ITGA2', 'commot-user_database-COL6A6-ITGA3', 'commot-user_database-COL6A6-ITGA1', 'commot-user_database-COL6A6-SDC1', 'commot-user_database-COL6A6-GP6', 'commot-user_database-COL6A6-ITGAV', 'commot-user_database-COL6A6-CD44', 'commot-user_database-COL6A6-ITGA9', 'commot-user_database-CD274-PDCD1', 'commot-user_database-THBS3-CD47', 'commot-user_database-THBS3-SDC4', 'commot-user_database-THBS3-ITGB1', 'commot-user_database-THBS3-ITGA3', 'commot-user_database-THBS3-SDC1', 'commot-user_database-THBS3-CD36', 'commot-user_database-THBS3-ITGAV', 'commot-user_database-HLA-DRB5-CD4', 'commot-user_database-CD40LG-ITGB2', 'commot-user_database-CD40LG-ITGB1', 'commot-user_database-CD40LG-CD40', 'commot-user_database-CD40LG-ITGA5', 'commot-user_database-CD40LG-ITGAM', 'commot-user_database-TIGIT-NECTIN2', 'commot-user_database-TIGIT-PVR', 'commot-user_database-CLCF1-IL6ST', 'commot-user_database-CLCF1-LIFR', 'commot-user_database-EFNA5-EPHB2', 'commot-user_database-EFNA5-EPHA3', 'commot-user_database-EFNA5-EPHA1', 'commot-user_database-EFNA5-EPHA2', 'commot-user_database-EFNA5-EPHA4', 'commot-user_database-NFASC-CNTNAP1', 'commot-user_database-NFASC-CNTN1', 'commot-user_database-IL15-IL2RG', 'commot-user_database-IL15-IL2RB', 'commot-user_database-IL15-IL15RA', 'commot-user_database-PDGFA-PDGFRA', 'commot-user_database-PDGFA-PDGFRB', 'commot-user_database-LAMA3-ITGA7', 'commot-user_database-LAMA3-ITGB1', 'commot-user_database-LAMA3-SV2C', 'commot-user_database-LAMA3-DAG1', 'commot-user_database-LAMA3-ITGB8', 'commot-user_database-LAMA3-ITGA2', 'commot-user_database-LAMA3-ITGA3', 'commot-user_database-LAMA3-ITGA1', 'commot-user_database-LAMA3-SV2B', 'commot-user_database-LAMA3-ITGB4', 'commot-user_database-LAMA3-ITGAV', 'commot-user_database-LAMA3-CD44', 'commot-user_database-LAMA3-ITGA9', 'commot-user_database-LAMA3-ITGA6', 'commot-user_database-CDH5-CDH5', 'commot-user_database-NAMPT-ITGB1', 'commot-user_database-NAMPT-ITGA5', 'commot-user_database-NAMPT-INSR', 'commot-user_database-CCL17-CCR4', 'commot-user_database-WNT4-FZD7', 'commot-user_database-WNT4-LRP6', 'commot-user_database-WNT4-FZD2', 'commot-user_database-WNT4-FZD8', 'commot-user_database-WNT4-FZD6', 'commot-user_database-WNT4-LRP5', 'commot-user_database-WNT4-FZD3', 'commot-user_database-RELN-ITGB1', 'commot-user_database-RELN-ITGA3', 'commot-user_database-WNT10A-FZD7', 'commot-user_database-WNT10A-LRP6', 'commot-user_database-WNT10A-FZD2', 'commot-user_database-WNT10A-FZD8', 'commot-user_database-WNT10A-FZD6', 'commot-user_database-WNT10A-LRP5', 'commot-user_database-WNT10A-FZD3', 'commot-user_database-FREM1-ITGB1', 'commot-user_database-FREM1-ITGA8', 'commot-user_database ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# Get spatial coordinates
coords = adata.obsm['spatial']

# Randomly select a point
random_idx = random.randint(0, len(coords) - 1)
random_point = coords[random_idx]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plot all points
ax.scatter(coords[:, 0], coords[:, 1], s=5, alpha=0.5, color='gray')

# Plot the randomly selected point
ax.scatter(random_point[0], random_point[1], s=50, color='red', label='Random point')

# Draw a circle with radius 800 around the random point
circle = plt.Circle((random_point[0], random_point[1]), 400, fill=False, color='blue', linestyle='--', label='800 radius')
ax.add_patch(circle)

# Set labels and title
ax.set_xlabel('X coordinate')
ax.set_ylabel('Y coordinate')
ax.set_title('Spatial coordinates with random point and 800 radius')
ax.legend()

# Set equal aspect ratio
ax.set_aspect('equal')

plt.tight_layout()
plt.show()

# %%
adata = init_received_ligands(
    adata, 
    radius=400, 
    contact_distance=50, 
    cell_threshes=cell_threshes
)
adata
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# AnnData object with n_obs × n_vars = 5778 × 3333
#     obs: 'cell_type', 'author_cell_type', 'cell_type_int', 'banksy_celltypes'
#     uns: 'cell_type_int_colors', 'commot-user_database-info', 'commot_cluster-cell_type-user_database-TGFB1-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB1-TGFBR2', 'commot_cluster-cell_type-user_database-TGFB2-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB2-TGFBR2', 'commot_cluster-cell_type-user_database-TGFB3-TGFBR1', 'commot_cluster-cell_type-user_database-TGFB3-TGFBR2', 'commot_cluster-cell_type-user_database-BMP2-BMPR1A', 'commot_cluster-cell_type-user_database-BMP2-BMPR2', 'commot_cluster-cell_type-user_database-BMP2-BMPR1B', 'commot_cluster-cell_type-user_database-GDF7-BMPR1A', 'commot_cluster-cell_type-user_database-GDF7-BMPR2', 'commot_cluster-cell_type-user_database-GDF7-BMPR1B', 'commot_cluster-cell_type-user_database-BMP6-BMPR2', 'commot_cluster-cell_type-user_database-BMP6-BMPR1A', 'commot_cluster-cell_type-user_database-BMP6-BMPR1B', 'commot_cluster-cell_type-user_database-BMP7-BMPR2', 'commot_cluster-cell_type-user_database-BMP7-BMPR1A', 'commot_cluster-cell_type-user_database-BMP7-BMPR1B', 'commot_cluster-cell_type-user_database-BMP8A-BMPR2', 'commot_cluster-cell_type-user_database-BMP8A-BMPR1A', 'commot_cluster-cell_type-user_database-BMP8A-BMPR1B', 'commot_cluster-cell_type-user_database-BMP8B-BMPR2', 'commot_cluster-cell_type-user_database-BMP8B-BMPR1A', 'commot_cluster-cell_type-user_database-BMP8B-BMPR1B', 'commot_cluster-cell_type-user_database-GDF11-TGFBR1', 'commot_cluster-cell_type-user_database-WNT10A-LRP5', 'commot_cluster-cell_type-user_database-WNT10A-FZD2', 'commot_cluster-cell_type-user_database-WNT10A-FZD3', 'commot_cluster-cell_type-user_database-WNT10A-FZD6', 'commot_cluster-cell_type-user_database-WNT10A-FZD7', 'commot_cluster-cell_type-user_database-WNT10A-FZD8', 'commot_cluster-cell_type-user_database-WNT10B-LRP5', 'commot_cluster-cell_type-user_database-WNT10B-FZD2', 'commot_cluster-cell_type-user_database-WNT10B-FZD3', 'commot_cluster-cell_type-user_database-WNT10B-FZD6', 'commot_cluster-cell_type-user_database-WNT10B-FZD7', 'commot_cluster-cell_type-user_database-WNT10B-FZD8', 'commot_cluster-cell_type-user_database-WNT16-LRP5', 'commot_cluster-cell_type-user_database-WNT16-FZD2', 'commot_cluster-cell_type-user_database-WNT16-FZD3', 'commot_cluster-cell_type-user_database-WNT16-FZD6', 'commot_cluster-cell_type-user_database-WNT16-FZD7', 'commot_cluster-cell_type-user_database-WNT16-FZD8', 'commot_cluster-cell_type-user_database-WNT2B-LRP5', 'commot_cluster-cell_type-user_database-WNT2B-FZD2', 'commot_cluster-cell_type-user_database-WNT2B-FZD3', 'commot_cluster-cell_type-user_database-WNT2B-FZD6', 'commot_cluster-cell_type-user_database-WNT2B-FZD7', 'commot_cluster-cell_type-user_database-WNT2B-FZD8', 'commot_cluster-cell_type-user_database-WNT3-LRP5', 'commot_cluster-cell_type-user_database-WNT3-FZD2', 'commot_cluster-cell_type-user_database-WNT3-FZD3', 'commot_cluster-cell_type-user_database-WNT3-FZD6', 'commot_cluster-cell_type-user_database-WNT3-FZD7', 'commot_cluster-cell_type-user_database-WNT3-FZD8', 'commot_cluster-cell_type-user_database-WNT4-LRP5', 'commot_cluster-cell_type-user_database-WNT4-FZD2', 'commot_cluster-cell_type-user_database-WNT4-FZD3', 'commot_cluster-cell_type-user_database-WNT4-FZD6', 'commot_cluster-cell_type-user_database-WNT4-FZD7', 'commot_cluster-cell_type-user_database-WNT4-FZD8', 'commot_cluster-cell_type-user_database-WNT6-LRP5', 'commot_cluster-cell_type-user_database-WNT6-FZD2', 'commot_cluster-cell_type-user_database-WNT6-FZD3', 'commot_cluster-cell_type-user_database-WNT6-FZD6', 'commot_cluster-cell_type-user_database-WNT6-FZD7', 'commot_cluster-cell_type-user_database-WNT6-FZD8', 'commot_cluster-cell_type-user_database-WNT7A-LRP5', 'commot_cluster-cell_type-user_database-WNT7A-FZD2', 'commot_cluster-cell_type-user_database-WNT7A-FZD3', 'commot_cluster-cell_type-user_database-WNT7A-FZD6', 'commot_cluster-cell_type-user_database-WNT7A-FZD7', 'commot_cluster-cell_type-user_database-WNT7A-FZD8', 'commot_cluster-cell_type-user_database-WNT ...
#     obsm: 'spatial', 'spatial_unscaled', 'commot-user_database-sum-sender', 'commot-user_database-sum-receiver'
#     layers: 'imputed_count', 'normalized_count'
#     obsp: 'commot-user_database-HLA-DOA-CD4', 'commot-user_database-CCL2-CCR2', 'commot-user_database-TAC4-TACR1', 'commot-user_database-VSIR-IGSF11', 'commot-user_database-DLL4-NOTCH1', 'commot-user_database-DLL4-NOTCH4', 'commot-user_database-DLL4-NOTCH2', 'commot-user_database-DLL4-NOTCH3', 'commot-user_database-HLA-DRA-CD4', 'commot-user_database-HLA-B-CD8A', 'commot-user_database-HLA-B-CD8B', 'commot-user_database-HLA-B-CD8B2', 'commot-user_database-PRSS3-PARD3', 'commot-user_database-PRSS3-F2R', 'commot-user_database-PRSS3-F2RL3', 'commot-user_database-PRSS3-F2RL2', 'commot-user_database-IL6-IL6R', 'commot-user_database-IL6-IL6ST', 'commot-user_database-PRSS2-PARD3', 'commot-user_database-PRSS2-F2R', 'commot-user_database-PRSS2-F2RL3', 'commot-user_database-PRSS2-F2RL2', 'commot-user_database-TNFSF15-TNFRSF25', 'commot-user_database-ALCAM-CD6', 'commot-user_database-BTLA-TNFRSF14', 'commot-user_database-IGF1-ITGB4', 'commot-user_database-IGF1-IGF1R', 'commot-user_database-IGF1-ITGAV', 'commot-user_database-IGF1-ITGA6', 'commot-user_database-PTPRM-PTPRM', 'commot-user_database-CD70-CD27', 'commot-user_database-COL6A6-ITGA10', 'commot-user_database-COL6A6-SDC4', 'commot-user_database-COL6A6-ITGA11', 'commot-user_database-COL6A6-ITGB1', 'commot-user_database-COL6A6-ITGB8', 'commot-user_database-COL6A6-ITGA2', 'commot-user_database-COL6A6-ITGA3', 'commot-user_database-COL6A6-ITGA1', 'commot-user_database-COL6A6-SDC1', 'commot-user_database-COL6A6-GP6', 'commot-user_database-COL6A6-ITGAV', 'commot-user_database-COL6A6-CD44', 'commot-user_database-COL6A6-ITGA9', 'commot-user_database-CD274-PDCD1', 'commot-user_database-THBS3-CD47', 'commot-user_database-THBS3-SDC4', 'commot-user_database-THBS3-ITGB1', 'commot-user_database-THBS3-ITGA3', 'commot-user_database-THBS3-SDC1', 'commot-user_database-THBS3-CD36', 'commot-user_database-THBS3-ITGAV', 'commot-user_database-HLA-DRB5-CD4', 'commot-user_database-CD40LG-ITGB2', 'commot-user_database-CD40LG-ITGB1', 'commot-user_database-CD40LG-CD40', 'commot-user_database-CD40LG-ITGA5', 'commot-user_database-CD40LG-ITGAM', 'commot-user_database-TIGIT-NECTIN2', 'commot-user_database-TIGIT-PVR', 'commot-user_database-CLCF1-IL6ST', 'commot-user_database-CLCF1-LIFR', 'commot-user_database-EFNA5-EPHB2', 'commot-user_database-EFNA5-EPHA3', 'commot-user_database-EFNA5-EPHA1', 'commot-user_database-EFNA5-EPHA2', 'commot-user_database-EFNA5-EPHA4', 'commot-user_database-NFASC-CNTNAP1', 'commot-user_database-NFASC-CNTN1', 'commot-user_database-IL15-IL2RG', 'commot-user_database-IL15-IL2RB', 'commot-user_database-IL15-IL15RA', 'commot-user_database-PDGFA-PDGFRA', 'commot-user_database-PDGFA-PDGFRB', 'commot-user_database-LAMA3-ITGA7', 'commot-user_database-LAMA3-ITGB1', 'commot-user_database-LAMA3-SV2C', 'commot-user_database-LAMA3-DAG1', 'commot-user_database-LAMA3-ITGB8', 'commot-user_database-LAMA3-ITGA2', 'commot-user_database-LAMA3-ITGA3', 'commot-user_database-LAMA3-ITGA1', 'commot-user_database-LAMA3-SV2B', 'commot-user_database-LAMA3-ITGB4', 'commot-user_database-LAMA3-ITGAV', 'commot-user_database-LAMA3-CD44', 'commot-user_database-LAMA3-ITGA9', 'commot-user_database-LAMA3-ITGA6', 'commot-user_database-CDH5-CDH5', 'commot-user_database-NAMPT-ITGB1', 'commot-user_database-NAMPT-ITGA5', 'commot-user_database-NAMPT-INSR', 'commot-user_database-CCL17-CCR4', 'commot-user_database-WNT4-FZD7', 'commot-user_database-WNT4-LRP6', 'commot-user_database-WNT4-FZD2', 'commot-user_database-WNT4-FZD8', 'commot-user_database-WNT4-FZD6', 'commot-user_database-WNT4-LRP5', 'commot-user_database-WNT4-FZD3', 'commot-user_database-RELN-ITGB1', 'commot-user_database-RELN-ITGA3', 'commot-user_database-WNT10A-FZD7', 'commot-user_database-WNT10A-LRP6', 'commot-user_database-WNT10A-FZD2', 'commot-user_database-WNT10A-FZD8', 'commot-user_database-WNT10A-FZD6', 'commot-user_database-WNT10A-LRP5', 'commot-user_database-WNT10A-FZD3', 'commot-user_database-FREM1-ITGB1', 'commot-user_database-FREM1-ITGA8', 'commot-user_database ...

# %%
keys = list(adata.obsm.keys())
for key in keys:
    if 'commot' in key:
        del adata.obsm[key]
        
keys = list(adata.uns.keys())
for key in keys:
    if 'commot' in key:
        del adata.uns[key]
        
keys = list(adata.obsp.keys())
for key in keys:
    if 'commot' in key:
        del adata.obsp[key]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5778 × 3333
#     obs: 'cell_type', 'author_cell_type', 'cell_type_int', 'banksy_celltypes'
#     uns: 'cell_type_int_colors', 'cell_thresholds', 'received_ligands', 'received_ligands_tfl'
#     obsm: 'spatial', 'spatial_unscaled'
#     layers: 'imputed_count', 'normalized_count'

# %%
adata.write_h5ad('/Users/koush/Desktop/training_data/snrna_human_tonsil.h5ad')
