# %%
import commot as ct
import scanpy as sc
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ### Run Commot

# %%
adata = sc.read_h5ad('/Users/allywang/Desktop/work/S2025/SpaceOracle/data/training_data_2025/mouse_kidney_13.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 8509 × 3058
#     obs: 'ct1', 'ct2', 'ct3', 'ct4', 'cond', 'medulla_cortex', 'domain', 'cell_type', 'cell_type_int'
#     uns: 'cell_type_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial', 'spatial_unscaled'
#     varm: 'PCs'
#     layers: 'imputed_count', 'normalized_count', 'raw_count'
#     obsp: 'connectivities', 'distances'

# %%
# adata.X = adata.layers['imputed_count']
adata.X = adata.layers['normalized_count']

# %%
df_ligrec = ct.pp.ligand_receptor_database(
    database='CellChat', 
    species='mouse', 
    signaling_type=None
)
    
df_ligrec.columns = ['ligand', 'receptor', 'pathway', 'signaling']  

df_ligrec['name'] = df_ligrec['ligand'] + '-' + df_ligrec['receptor']
len(df_ligrec['name'].unique())
# Out:
# 2017

# %%
import sys
sys.path.append('../../src')
from spaceoracle.tools.network import expand_paired_interactions

expanded = expand_paired_interactions(df_ligrec)
genes = set(expanded.ligand) | set(expanded.receptor)
genes = list(genes)

expanded
# Out:
#      ligand receptor pathway           signaling                 name
# 0     Tgfb1   Tgfbr1    TGFb  Secreted Signaling  Tgfb1-Tgfbr1_Tgfbr2
# 0     Tgfb1   Tgfbr2    TGFb  Secreted Signaling  Tgfb1-Tgfbr1_Tgfbr2
# 1     Tgfb2   Tgfbr1    TGFb  Secreted Signaling  Tgfb2-Tgfbr1_Tgfbr2
# 1     Tgfb2   Tgfbr2    TGFb  Secreted Signaling  Tgfb2-Tgfbr1_Tgfbr2
# 2     Tgfb3   Tgfbr1    TGFb  Secreted Signaling  Tgfb3-Tgfbr1_Tgfbr2
# ...     ...      ...     ...                 ...                  ...
# 2016  Itga9    Vcam1    VCAM   Cell-Cell Contact    Itga9_Itgb1-Vcam1
# 2016  Itgb1    Vcam1    VCAM   Cell-Cell Contact    Itga9_Itgb1-Vcam1
# 2017  Itga4    Vcam1    VCAM   Cell-Cell Contact    Itga4_Itgb7-Vcam1
# 2017  Itgb7    Vcam1    VCAM   Cell-Cell Contact    Itga4_Itgb7-Vcam1
# 2018   Vsir   Igsf11   VISTA   Cell-Cell Contact          Vsir-Igsf11
#
# [3012 rows x 5 columns]

# %%
expanded = expanded[expanded.ligand.isin(adata.var_names) & expanded.receptor.isin(adata.var_names)]
expanded
# Out:
#      ligand receptor pathway           signaling                       name
# 1     Tgfb2   Tgfbr1    TGFb  Secreted Signaling        Tgfb2-Tgfbr1_Tgfbr2
# 2     Tgfb3   Tgfbr1    TGFb  Secreted Signaling        Tgfb3-Tgfbr1_Tgfbr2
# 10    Tgfb2   Tgfbr1    TGFb  Secreted Signaling  Tgfb2-Acvr1_Tgfbr1_Tgfbr2
# 11    Tgfb3   Tgfbr1    TGFb  Secreted Signaling  Tgfb3-Acvr1_Tgfbr1_Tgfbr2
# 15     Bmp2   Bmpr1b     BMP  Secreted Signaling         Bmp2-Bmpr1b_Acvr2a
# ...     ...      ...     ...                 ...                        ...
# 2012   Thy1    Itgav    THY1   Cell-Cell Contact           Thy1-Itgav_Itgb3
# 2012   Thy1    Itgb3    THY1   Cell-Cell Contact           Thy1-Itgav_Itgb3
# 2015  Itga4    Vcam1    VCAM   Cell-Cell Contact          Itga4_Itgb1-Vcam1
# 2017  Itga4    Vcam1    VCAM   Cell-Cell Contact          Itga4_Itgb7-Vcam1
# 2017  Itgb7    Vcam1    VCAM   Cell-Cell Contact          Itga4_Itgb7-Vcam1
#
# [396 rows x 5 columns]

# %%
ct.tl.spatial_communication(adata,
    database_name='user_database', 
    # df_ligrec=df_ligrec, 
    df_ligrec=expanded, 
    dis_thr=200, 
    # heteromeric=True
    heteromeric=False
)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 8509 × 3058
#     obs: 'ct1', 'ct2', 'ct3', 'ct4', 'cond', 'medulla_cortex', 'domain', 'cell_type', 'cell_type_int'
#     uns: 'cell_type_colors', 'neighbors', 'pca', 'umap', 'commot-user_database-info'
#     obsm: 'X_pca', 'X_umap', 'spatial', 'spatial_unscaled', 'commot-user_database-sum-sender', 'commot-user_database-sum-receiver'
#     varm: 'PCs'
#     layers: 'imputed_count', 'normalized_count', 'raw_count'
#     obsp: 'connectivities', 'distances', 'commot-user_database-H2-Q6-Cd8b1', 'commot-user_database-H2-Q6-Cd8a', 'commot-user_database-Cadm1-Cadm1', 'commot-user_database-Il27-Il27ra', 'commot-user_database-Egf-Egfr', 'commot-user_database-Tnfsf9-Tnfrsf9', 'commot-user_database-Pdgfc-Pdgfra', 'commot-user_database-H2-Q10-Cd8b1', 'commot-user_database-H2-Q10-Cd8a', 'commot-user_database-Tnf-Tnfrsf1b', 'commot-user_database-Fasl-Fas', 'commot-user_database-Efna5-Epha4', 'commot-user_database-Efna5-Epha3', 'commot-user_database-Efna5-Epha1', 'commot-user_database-Tnc-Itgav', 'commot-user_database-Tnc-Sdc1', 'commot-user_database-Tnc-Itga8', 'commot-user_database-Tnc-Sdc4', 'commot-user_database-Tnc-Itgb3', 'commot-user_database-Tnc-Itgb6', 'commot-user_database-Wnt11-Fzd5', 'commot-user_database-Itga4-Vcam1', 'commot-user_database-Il1b-Il1r1', 'commot-user_database-Il1b-Il1rap', 'commot-user_database-Jag1-Notch4', 'commot-user_database-Jag1-Notch3', 'commot-user_database-Esam-Esam', 'commot-user_database-Col4a1-Itgav', 'commot-user_database-Col4a1-Itgb8', 'commot-user_database-Col4a1-Sdc1', 'commot-user_database-Col4a1-Itga1', 'commot-user_database-Col4a1-Sdc4', 'commot-user_database-Col4a1-Itga2', 'commot-user_database-Col4a1-Cd44', 'commot-user_database-Cd80-Cd274', 'commot-user_database-Cd80-Cd28', 'commot-user_database-Cd80-Ctla4', 'commot-user_database-Ccl2-Ccr2', 'commot-user_database-Cd209a-Ceacam1', 'commot-user_database-Il17c-Il17ra', 'commot-user_database-Sema6d-Tyrobp', 'commot-user_database-Sema6d-Kdr', 'commot-user_database-Negr1-Negr1', 'commot-user_database-Guca2b-Gucy2c', 'commot-user_database-Fn1-Itgav', 'commot-user_database-Fn1-Itga4', 'commot-user_database-Fn1-Itgb7', 'commot-user_database-Fn1-Itgb8', 'commot-user_database-Fn1-Sdc1', 'commot-user_database-Fn1-Itga8', 'commot-user_database-Fn1-Sdc4', 'commot-user_database-Fn1-Itgb3', 'commot-user_database-Fn1-Cd44', 'commot-user_database-Fn1-Itgb6', 'commot-user_database-Col6a2-Itgav', 'commot-user_database-Col6a2-Itgb8', 'commot-user_database-Col6a2-Sdc1', 'commot-user_database-Col6a2-Itga1', 'commot-user_database-Col6a2-Sdc4', 'commot-user_database-Col6a2-Itga2', 'commot-user_database-Col6a2-Cd44', 'commot-user_database-Cxcl10-Cxcr3', 'commot-user_database-Col1a1-Itgav', 'commot-user_database-Col1a1-Itgb8', 'commot-user_database-Col1a1-Sdc1', 'commot-user_database-Col1a1-Itga1', 'commot-user_database-Col1a1-Sdc4', 'commot-user_database-Col1a1-Itga2', 'commot-user_database-Col1a1-Cd44', 'commot-user_database-Bmp2-Bmpr1b', 'commot-user_database-Pecam1-Pecam1', 'commot-user_database-Vwf-Itgav', 'commot-user_database-Vwf-Itgb3', 'commot-user_database-Col4a6-Itgav', 'commot-user_database-Col4a6-Itgb8', 'commot-user_database-Col4a6-Sdc1', 'commot-user_database-Col4a6-Itga1', 'commot-user_database-Col4a6-Sdc4', 'commot-user_database-Col4a6-Itga2', 'commot-user_database-Col4a6-Cd44', 'commot-user_database-Btc-Egfr', 'commot-user_database-Btc-Erbb4', 'commot-user_database-Vegfc-Kdr', 'commot-user_database-Ccl3-Ccr5', 'commot-user_database-Ccl3-Ccr1', 'commot-user_database-Angpt2-Tek', 'commot-user_database-Sema3g-Nrp2', 'commot-user_database-Sema3g-Plxna3', 'commot-user_database-Sema3g-Plxna2', 'commot-user_database-Col6a1-Itgav', 'commot-user_database-Col6a1-Itgb8', 'commot-user_database-Col6a1-Sdc1', 'commot-user_database-Col6a1-Itga1', 'commot-user_database-Col6a1-Sdc4', 'commot-user_database-Col6a1-Itga2', 'commot-user_database-Col6a1-Cd44', 'commot-user_database-H2-Q7-Cd8b1', 'commot-user_database-H2-Q7-Cd8a', 'commot-user_database-Angpt1-Tek', 'commot-user_database-Sema5a-Plxna3', 'commot-user_database-Sema5a-Plxnb3', 'commot-user_database-Spp1-Itgav', 'commot-user_database-Spp1-Itga4', 'commot-user_database-Spp1-Itga8', 'commot-user_database-Spp1-Itgb3', 'commot-user_database-Spp1-Cd44', 'commot-user_database-Spp1-Itgb6', 'commot-user_database-Wnt4-Fzd5', 'commot-user_database-Igf1-Itgav', 'commot-user_database-Igf1-Itgb3', 'commot-user_database-Vegfa-Flt1', 'co ...

# %%
adata.write_h5ad('commot.h5ad')
adata = sc.read_h5ad('commot.h5ad')

# %%
# lr_info = {k.replace('commot-user_database-', ''): v for k, v in adata.obsp.items() if 'commot-user_database-' in k}
# len(lr_info)

# %%
# df_ligrec = df_ligrec[df_ligrec['name'].isin(lr_info.keys())]
# df_ligrec['signaling'].value_counts()

# %% [markdown]
# ### Get cluster communication scores

# %%
expanded['rename'] = expanded['ligand'] + '-' + expanded['receptor']

# %%
from tqdm import tqdm
import commot as ct

for name in tqdm(expanded['rename'].unique()):

    ct.tl.cluster_communication(adata, database_name='user_database', pathway_name=name, clustering='cell_type',
        random_seed=12, n_permutations=100)
# Out:
# 100%|██████████| 326/326 [05:37<00:00,  1.03s/it]

# %%
adata.write_h5ad('commot_cluster.h5ad')
adata = sc.read_h5ad('commot_cluster.h5ad')

# %%
from collections import defaultdict
data_dict = defaultdict(dict)

for name in expanded['rename']:
    data_dict[name]['communication_matrix'] = adata.uns[f'commot_cluster-cell_type-user_database-{name}']['communication_matrix']
    data_dict[name]['communication_pvalue'] = adata.uns[f'commot_cluster-cell_type-user_database-{name}']['communication_pvalue']

import pickle
with open('/Users/allywang/Desktop/work/S2025/SpaceOracle/data/training_data_2025/commot_kidney_communication.pkl', 'wb') as f:
    pickle.dump(data_dict, f)

# %%
# check outputs

import pickle
with open('/Users/allywang/Desktop/work/S2025/SpaceOracle/data/training_data_2025/commot_kidney_communication.pkl', 'rb') as f:
    info = pickle.load(f)

len(info.keys())
# Out:
# 326

# %%
def get_sig_interactions(value_matrix, p_matrix, pval=0.3):
    p_matrix = np.where(p_matrix < pval, 1, 0)
    return value_matrix * p_matrix

interactions = {}
for lig, rec in tqdm(zip(expanded['ligand'], expanded['receptor'])):
    name = lig + '-' + rec

    if name in info.keys():

        value_matrix = info[name]['communication_matrix']
        p_matrix = info[name]['communication_pvalue']

        sig_matrix = get_sig_interactions(value_matrix, p_matrix)
        
        if sig_matrix.sum().sum() > 0:
            interactions[name] = sig_matrix
    
len(interactions)
# Out:
# 396it [00:00, 6577.53it/s]
# 326

# %% [markdown]
# ### Get expanded LR masks

# %%
interactions.keys()
# Out:
# dict_keys(['Tgfb2-Tgfbr1', 'Tgfb3-Tgfbr1', 'Bmp2-Bmpr1b', 'Bmp6-Bmpr1b', 'Wnt4-Fzd5', 'Wnt11-Fzd5', 'Egf-Egfr', 'Areg-Egfr', 'Btc-Egfr', 'Btc-Erbb4', 'Hbegf-Egfr', 'Hbegf-Erbb4', 'Nrg1-Erbb4', 'Nrg2-Erbb4', 'Nrg4-Erbb4', 'Nrg1-Itgav', 'Nrg1-Itgb3', 'Pdgfc-Pdgfra', 'Pdgfd-Pdgfrb', 'Vegfa-Flt1', 'Vegfa-Kdr', 'Vegfc-Kdr', 'Igf1-Itgav', 'Igf1-Itgb3', 'Apln-Aplnr', 'Ccl5-Ccr1', 'Ccl3-Ccr1', 'Ccl9-Ccr1', 'Ccl6-Ccr1', 'Ccl6-Ccr2', 'Ccl2-Ccr2', 'Ccl12-Ccr2', 'Ccl27a-Ccr2', 'Ccl4-Ccr5', 'Ccl5-Ccr5', 'Ccl3-Ccr5', 'Cxcl1-Cxcr2', 'Cxcl2-Cxcr2', 'Pf4-Cxcr3', 'Cxcl9-Cxcr3', 'Cxcl10-Cxcr3', 'Cxcl12-Cxcr4', 'Cxcl12-Ackr3', 'Mif-Cd74', 'Mif-Cxcr4', 'Mif-Cd44', 'Mif-Cxcr2', 'Mif-Ackr3', 'Xcl1-Xcr1', 'Il27-Il27ra', 'Il1b-Il1r1', 'Il1b-Il1rap', 'Il17c-Il17ra', 'Tnf-Tnfrsf1b', 'Fasl-Fas', 'Tnfsf9-Tnfrsf9', 'Cd40lg-Itgb3', 'Cd40lg-Itgam', 'Spp1-Cd44', 'Spp1-Itgav', 'Spp1-Itgb3', 'Spp1-Itgb6', 'Spp1-Itga4', 'Spp1-Itga8', 'Angpt1-Tek', 'Angpt2-Tek', 'Mdk-Sdc1', 'Mdk-Sdc4', 'Mdk-Itga4', 'Mdk-Lrp1', 'Ptn-Sdc1', 'Ptn-Sdc4', 'Ptn-Itgav', 'Ptn-Itgb3', 'C3-Cr2', 'C3-Itgam', 'C3-Itgax', 'Edn1-Ednrb', 'Gzma-F2r', 'Gzma-Pard3', 'Kitl-Kit', 'Hgf-Met', 'Ntf3-Ntrk3', 'Sema3a-Nrp1', 'Sema3a-Plxna2', 'Sema3a-Plxna3', 'Sema3c-Nrp1', 'Sema3c-Plxna2', 'Sema3c-Plxna3', 'Sema3d-Nrp1', 'Sema3d-Plxna2', 'Sema3d-Plxna3', 'Sema3c-Nrp2', 'Sema3d-Nrp2', 'Sema3g-Nrp2', 'Sema3g-Plxna2', 'Sema3g-Plxna3', 'Anxa1-Fpr2', 'Anxa1-Fpr1', 'Apela-Aplnr', 'Calca-Calcrl', 'Guca2b-Gucy2c', 'Btla-Tnfrsf14', 'Col1a1-Itga1', 'Col1a2-Itga1', 'Col4a1-Itga1', 'Col4a2-Itga1', 'Col4a3-Itga1', 'Col4a4-Itga1', 'Col4a6-Itga1', 'Col6a1-Itga1', 'Col6a2-Itga1', 'Col6a3-Itga1', 'Col9a3-Itga1', 'Col1a1-Itga2', 'Col1a2-Itga2', 'Col4a1-Itga2', 'Col4a2-Itga2', 'Col4a3-Itga2', 'Col4a4-Itga2', 'Col4a6-Itga2', 'Col6a1-Itga2', 'Col6a2-Itga2', 'Col6a3-Itga2', 'Col9a3-Itga2', 'Fn1-Itga4', 'Fn1-Itga8', 'Lama2-Itga1', 'Lama3-Itga1', 'Lama4-Itga1', 'Lamb1-Itga1', 'Lamb3-Itga1', 'Lamc2-Itga1', 'Lama2-Itga2', 'Lama3-Itga2', 'Lama4-Itga2', 'Lamb1-Itga2', 'Lamb3-Itga2', 'Lamc2-Itga2', 'Tnc-Itga8', 'Tnxb-Itga8', 'Npnt-Itga8', 'Fras1-Itga8', 'Frem1-Itga8', 'Fn1-Itgav', 'Fn1-Itgb7', 'Fn1-Itgb3', 'Vwf-Itgav', 'Vwf-Itgb3', 'Tnc-Itgav', 'Tnc-Itgb3', 'Tnxb-Itgav', 'Tnxb-Itgb3', 'Thbs1-Itgav', 'Thbs1-Itgb3', 'Tnc-Itgb6', 'Tnxb-Itgb6', 'Fn1-Itgb6', 'Fn1-Itgb8', 'Lama2-Itgav', 'Lama2-Itgb8', 'Lama3-Itgav', 'Lama3-Itgb8', 'Lama4-Itgav', 'Lama4-Itgb8', 'Lamb1-Itgav', 'Lamb1-Itgb8', 'Lamb3-Itgav', 'Lamb3-Itgb8', 'Lamc2-Itgav', 'Lamc2-Itgb8', 'Col1a1-Itgav', 'Col1a1-Itgb8', 'Col1a2-Itgav', 'Col1a2-Itgb8', 'Col4a1-Itgav', 'Col4a1-Itgb8', 'Col4a2-Itgav', 'Col4a2-Itgb8', 'Col4a3-Itgav', 'Col4a3-Itgb8', 'Col4a4-Itgav', 'Col4a4-Itgb8', 'Col4a6-Itgav', 'Col4a6-Itgb8', 'Col6a1-Itgav', 'Col6a1-Itgb8', 'Col6a2-Itgav', 'Col6a2-Itgb8', 'Col6a3-Itgav', 'Col6a3-Itgb8', 'Col9a3-Itgav', 'Col9a3-Itgb8', 'Fn1-Cd44', 'Col1a1-Cd44', 'Col1a2-Cd44', 'Col4a1-Cd44', 'Col4a2-Cd44', 'Col4a3-Cd44', 'Col4a4-Cd44', 'Col4a6-Cd44', 'Col6a1-Cd44', 'Col6a2-Cd44', 'Col6a3-Cd44', 'Col9a3-Cd44', 'Lama2-Cd44', 'Lama3-Cd44', 'Lama4-Cd44', 'Lamb1-Cd44', 'Lamb3-Cd44', 'Lamc2-Cd44', 'Col1a1-Sdc1', 'Col1a2-Sdc1', 'Col4a1-Sdc1', 'Col4a2-Sdc1', 'Col4a3-Sdc1', 'Col4a4-Sdc1', 'Col4a6-Sdc1', 'Col6a1-Sdc1', 'Col6a2-Sdc1', 'Col6a3-Sdc1', 'Col9a3-Sdc1', 'Fn1-Sdc1', 'Tnc-Sdc1', 'Tnxb-Sdc1', 'Thbs1-Sdc1', 'Col1a1-Sdc4', 'Col1a2-Sdc4', 'Col4a1-Sdc4', 'Col4a2-Sdc4', 'Col4a3-Sdc4', 'Col4a4-Sdc4', 'Col4a6-Sdc4', 'Col6a1-Sdc4', 'Col6a2-Sdc4', 'Col6a3-Sdc4', 'Col9a3-Sdc4', 'Fn1-Sdc4', 'Tnc-Sdc4', 'Tnxb-Sdc4', 'Thbs1-Sdc4', 'Thbs1-Cd36', 'Hspg2-Dag1', 'Lama2-Dag1', 'Lama3-Dag1', 'Lama4-Dag1', 'Lamb1-Dag1', 'Lamb3-Dag1', 'Lamc2-Dag1', 'Alcam-Cd6', 'Cadm1-Cadm1', 'Cd200-Cd200r1', 'Cd200-Cd200r4', 'Fcer2a-Itgam', 'Fcer2a-Itgax', 'Fcer2a-Itgav', 'Fcer2a-Itgb3', 'Fcer2a-Cr2', 'Cd34-Selp', 'Cd52-Siglecg', 'Cd6-Alcam', 'Cd80-Cd274', 'Cd80-Cd28', 'Cd80-Ctla4', 'Cd86-Cd28', 'Cd86-Ctla4', 'Cdh1-Cdh1', 'Cdh1-Itga2', 'Cdh1-Itgae', 'Cdh1-Itgb7', 'Cdh5-Cdh5', 'Cd209a-Ceacam1', 'Clec2i-Klrb1f', 'Efna1-Eph ...

# %%
# create cell x gene matrix
ct_masks = {ct: adata.obs['cell_type'] == ct for ct in adata.obs['cell_type'].unique()}

df = pd.DataFrame(index=adata.obs_names, columns=genes)
df = df.fillna(0)

for name in tqdm(interactions.keys(), total=len(interactions)):
    lig, rec = name.rsplit('-', 1)
    
    tmp = interactions[name].sum(axis=1)
    for ct, val in zip(interactions[name].index, tmp):
        df.loc[ct_masks[ct], lig] += tmp[ct]
    
    tmp = interactions[name].sum(axis=0)
    for ct, val in zip(interactions[name].columns, tmp):
        df.loc[ct_masks[ct], rec] += tmp[ct]

df.shape
# Out:
# 100%|██████████| 326/326 [00:03<00:00, 91.40it/s]
# (8509, 993)

# %%
print('Number of LR filtered using celltype specificity:')
np.where(df > 0, 1, 0).sum().sum() / (df.shape[0] * df.shape[1])
# Out:
# Number of LR filtered using celltype specificity:
# 0.15084555337829017

# %%
# df.to_parquet('/ix/djishnu/shared/djishnu_kor11/miscellaneous/kidney_commot_LRs.parquet')
df.to_parquet('/Users/allywang/Desktop/work/S2025/SpaceOracle/notebooks/mouse_kidney_survey/kidney_LRs.parquet')

# %%
df.columns[np.where(df.sum() > 0)]
# Out:
# Index(['Podxl', 'Cadm1', 'Il27', 'H2-Q10', 'Tnf', 'Efna5', 'Wnt11', 'Cd209a',
#        'Sema6d', 'Cxcl10',
#        ...
#        'Cd274', 'Calca', 'Klrk1', 'Il1r1', 'Sema3d', 'Fzd5', 'Tnfrsf1b',
#        'Sema3c', 'Cxcl12', 'Pdgfra'],
#       dtype='object', length=216)

# %% [markdown]
# ### Save params in adata

# %%
adata = sc.read_h5ad('/ix/djishnu/shared/djishnu_kor11/training_data_2025/mouse_kidney_13.h5ad')
adata

# %%
from spaceoracle.models.parallel_estimators import *

cell_threshes = pd.read_parquet('/ix/djishnu/shared/djishnu_kor11/commot_outputs/kidney_LRs.parquet')
adata.uns['cell_thresholds'] = cell_threshes
adata

# %%
adata = init_received_ligands(
    adata, 
    radius=200, 
    contact_distance=30, 
    cell_threshes=cell_threshes
)
adata

# %%
adata.write_h5ad('/ix/djishnu/shared/djishnu_kor11/training_data_2025/mouse_kidney_13.h5ad')
